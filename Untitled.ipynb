# %%
# %load_ext autoreload
# %autoreload 2
# %env CUPY_ACCELERATORS=cutensor,cub
# %env TENSORLY_BACKEND=cupy
# %env TENSORLY_TENALG_BACKEND=einsum

import tensorly as tl
import plotly.io as pio

pio.renderers.default = 'iframe'
tl.plugins.use_opt_einsum()
print(f'TensorLy backend: {tl.get_backend()}')
print(f'TensorLy algebra backend: {tl.tenalg.get_backend()}')
# Out:
# env: CUPY_ACCELERATORS=cutensor,cub
# env: TENSORLY_BACKEND=cupy
# env: TENSORLY_TENALG_BACKEND=einsum
# TensorLy backend: cupy
# TensorLy algebra backend: einsum

# %%
from scripts.moabb_erp import moabb_erp
from hoda.hoda import HODA
from hoda.cov import mode_scatter

# %load_ext line_profiler

# %%
moabb_erp('BNCI2014-008', 2)
# Out:
# BNCI2014-008-WithinSession:   0%|          | 0/1 [00:00<?, ?it/s]/data/leuven/352/vsc35289/miniconda3/envs/hoda-bci/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning:
#
# warnEpochs <Epochs | 4200 events (all good), 0 – 1 s (baseline off), ~65.9 MB, data loaded,
#  'Target': 700
#  'NonTarget': 3500>
# No hdf5_path provided, models will not be saved.
# fold=0, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  38%|███▊      | 24/64 [00:00<00:00, 125.23it/s]
# fold=0, theta=0, n_blocks=1
# fold=0, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  55%|█████▍    | 35/64 [00:00<00:00, 137.79it/s]
# fold=0, theta=0.1, n_blocks=1
# fold=0, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4):  34%|███▍      | 22/64 [00:00<00:00, 141.94it/s]
# fold=0, theta=0.2, n_blocks=1
# fold=0, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  27%|██▋       | 17/64 [00:00<00:00, 140.32it/s]
# fold=0, theta=0.3, n_blocks=1
# fold=0, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  20%|██        | 13/64 [00:00<00:00, 136.41it/s]
# fold=0, theta=0.4, n_blocks=1
# fold=0, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  16%|█▌        | 10/64 [00:00<00:00, 133.88it/s]
# fold=0, theta=0.5, n_blocks=1
# fold=0, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 18):  16%|█▌        | 10/64 [00:00<00:00, 131.86it/s]
# fold=0, theta=0.6, n_blocks=1
# fold=0, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 23):  16%|█▌        | 10/64 [00:00<00:00, 132.15it/s]
# fold=0, theta=0.7, n_blocks=1
# fold=0, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  12%|█▎        | 8/64 [00:00<00:00, 127.16it/s]
# fold=0, theta=0.8, n_blocks=1
# fold=0, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(4, 36):  12%|█▎        | 8/64 [00:00<00:00, 127.43it/s]
# fold=0, theta=0.9, n_blocks=1
# fold=0, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:01, 61.58it/s]
# fold=0, theta=1, n_blocks=1
# fold=1, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  73%|███████▎  | 47/64 [00:00<00:00, 146.81it/s]
# fold=1, theta=0, n_blocks=1
# fold=1, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  38%|███▊      | 24/64 [00:00<00:00, 143.36it/s]
# fold=1, theta=0.1, n_blocks=1
# fold=1, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 5):  45%|████▌     | 29/64 [00:00<00:00, 144.30it/s]
# fold=1, theta=0.2, n_blocks=1
# fold=1, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 8):  30%|██▉       | 19/64 [00:00<00:00, 140.25it/s]
# fold=1, theta=0.3, n_blocks=1
# fold=1, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 11):  22%|██▏       | 14/64 [00:00<00:00, 138.13it/s]
# fold=1, theta=0.4, n_blocks=1
# fold=1, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 15):  20%|██        | 13/64 [00:00<00:00, 137.37it/s]
# fold=1, theta=0.5, n_blocks=1
# fold=1, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  19%|█▉        | 12/64 [00:00<00:00, 135.31it/s]
# fold=1, theta=0.6, n_blocks=1
# fold=1, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 24):  17%|█▋        | 11/64 [00:00<00:00, 134.36it/s]
# fold=1, theta=0.7, n_blocks=1
# fold=1, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 30):  14%|█▍        | 9/64 [00:00<00:00, 132.21it/s]
# fold=1, theta=0.8, n_blocks=1
# fold=1, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(4, 36):  14%|█▍        | 9/64 [00:00<00:00, 132.57it/s]
# fold=1, theta=0.9, n_blocks=1
# fold=1, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 63.90it/s]
# fold=1, theta=1, n_blocks=1
# fold=2, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  56%|█████▋    | 36/64 [00:00<00:00, 146.01it/s]
# fold=2, theta=0, n_blocks=1
# fold=2, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  59%|█████▉    | 38/64 [00:00<00:00, 146.12it/s]
# fold=2, theta=0.1, n_blocks=1
# fold=2, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 5):  34%|███▍      | 22/64 [00:00<00:00, 144.41it/s]
# fold=2, theta=0.2, n_blocks=1
# fold=2, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 8):  22%|██▏       | 14/64 [00:00<00:00, 138.61it/s]
# fold=2, theta=0.3, n_blocks=1
# fold=2, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 11):  22%|██▏       | 14/64 [00:00<00:00, 139.63it/s]
# fold=2, theta=0.4, n_blocks=1
# fold=2, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 15):  20%|██        | 13/64 [00:00<00:00, 139.34it/s]
# fold=2, theta=0.5, n_blocks=1
# fold=2, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  19%|█▉        | 12/64 [00:00<00:00, 137.07it/s]
# fold=2, theta=0.6, n_blocks=1
# fold=2, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 24):  19%|█▉        | 12/64 [00:00<00:00, 136.73it/s]
# fold=2, theta=0.7, n_blocks=1
# fold=2, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  16%|█▌        | 10/64 [00:00<00:00, 136.14it/s]
# fold=2, theta=0.8, n_blocks=1
# fold=2, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(3, 36):  16%|█▌        | 10/64 [00:00<00:00, 134.65it/s]
# fold=2, theta=0.9, n_blocks=1
# fold=2, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.14it/s]
# fold=2, theta=1, n_blocks=1
# fold=3, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1): 100%|██████████| 64/64 [00:00<00:00, 151.77it/s]
# /vsc-hard-mounts/leuven-data/352/vsc35289/hoda-bci/src/hoda/hoda.py:358: UserWarning:
#
# Maximum number of iterations reached without convergence
# fold=3, theta=0, n_blocks=1
# fold=3, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  59%|█████▉    | 38/64 [00:00<00:00, 147.55it/s]
# fold=3, theta=0.1, n_blocks=1
# fold=3, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4): 100%|██████████| 64/64 [00:00<00:00, 152.29it/s]
# /vsc-hard-mounts/leuven-data/352/vsc35289/hoda-bci/src/hoda/hoda.py:358: UserWarning:
#
# Maximum number of iterations reached without convergence
# fold=3, theta=0.2, n_blocks=1
# fold=3, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  48%|████▊     | 31/64 [00:00<00:00, 146.34it/s]
# fold=3, theta=0.3, n_blocks=1
# fold=3, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  30%|██▉       | 19/64 [00:00<00:00, 142.92it/s]
# fold=3, theta=0.4, n_blocks=1
# fold=3, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  22%|██▏       | 14/64 [00:00<00:00, 140.15it/s]
# fold=3, theta=0.5, n_blocks=1
# fold=3, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 18):  19%|█▉        | 12/64 [00:00<00:00, 136.93it/s]
# fold=3, theta=0.6, n_blocks=1
# fold=3, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 23):  19%|█▉        | 12/64 [00:00<00:00, 136.91it/s]
# fold=3, theta=0.7, n_blocks=1
# fold=3, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  16%|█▌        | 10/64 [00:00<00:00, 136.14it/s]
# fold=3, theta=0.8, n_blocks=1
# fold=3, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(3, 36):  16%|█▌        | 10/64 [00:00<00:00, 135.88it/s]
# fold=3, theta=0.9, n_blocks=1
# fold=3, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.24it/s]
# fold=3, theta=1, n_blocks=1
# fold=4, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  53%|█████▎    | 34/64 [00:00<00:00, 146.83it/s]
# fold=4, theta=0, n_blocks=1
# fold=4, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  56%|█████▋    | 36/64 [00:00<00:00, 148.09it/s]
# fold=4, theta=0.1, n_blocks=1
# fold=4, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4):  61%|██████    | 39/64 [00:00<00:00, 146.52it/s]
# fold=4, theta=0.2, n_blocks=1
# fold=4, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  33%|███▎      | 21/64 [00:00<00:00, 143.42it/s]
# fold=4, theta=0.3, n_blocks=1
# fold=4, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  25%|██▌       | 16/64 [00:00<00:00, 139.97it/s]
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    8.0s
# fold=4, theta=0.4, n_blocks=1
# fold=4, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  20%|██        | 13/64 [00:00<00:00, 137.68it/s]
# fold=4, theta=0.5, n_blocks=1
# fold=4, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  20%|██        | 13/64 [00:00<00:00, 136.99it/s]
# fold=4, theta=0.6, n_blocks=1
# fold=4, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 23):  17%|█▋        | 11/64 [00:00<00:00, 131.15it/s]
# fold=4, theta=0.7, n_blocks=1
# fold=4, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  14%|█▍        | 9/64 [00:00<00:00, 132.71it/s]
# fold=4, theta=0.8, n_blocks=1
# fold=4, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(3, 36):  14%|█▍        | 9/64 [00:00<00:00, 132.71it/s]
# fold=4, theta=0.9, n_blocks=1
# fold=4, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 63.98it/s]
# fold=4, theta=1, n_blocks=1
# Fitting BTTDA with theta=1.0, n_blocks=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:01, 60.40it/s]
# Forward model :   0%|          | 0/63 [00:00<?, ?it/s]
# fold=0, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  30%|██▉       | 19/64 [00:00<00:00, 140.27it/s]
# fold=0, theta=0, n_blocks=1
# fold=0, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  34%|███▍      | 22/64 [00:00<00:00, 143.90it/s]
# fold=0, theta=0.1, n_blocks=1
# fold=0, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4):  33%|███▎      | 21/64 [00:00<00:00, 143.27it/s]
# fold=0, theta=0.2, n_blocks=1
# fold=0, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  28%|██▊       | 18/64 [00:00<00:00, 140.94it/s]
# fold=0, theta=0.3, n_blocks=1
# fold=0, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  22%|██▏       | 14/64 [00:00<00:00, 138.82it/s]
# fold=0, theta=0.4, n_blocks=1
# fold=0, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 13):  20%|██        | 13/64 [00:00<00:00, 136.65it/s]
# fold=0, theta=0.5, n_blocks=1
# fold=0, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 18):  17%|█▋        | 11/64 [00:00<00:00, 133.80it/s]
# fold=0, theta=0.6, n_blocks=1
# fold=0, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 23):  16%|█▌        | 10/64 [00:00<00:00, 133.30it/s]
# fold=0, theta=0.7, n_blocks=1
# fold=0, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  12%|█▎        | 8/64 [00:00<00:00, 132.33it/s]
# fold=0, theta=0.8, n_blocks=1
# fold=0, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(4, 35):  12%|█▎        | 8/64 [00:00<00:00, 127.96it/s]
# fold=0, theta=0.9, n_blocks=1
# fold=0, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.29it/s]
# fold=0, theta=1, n_blocks=1
# fold=1, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  45%|████▌     | 29/64 [00:00<00:00, 145.50it/s]
# fold=1, theta=0, n_blocks=1
# fold=1, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  64%|██████▍   | 41/64 [00:00<00:00, 148.12it/s]
# fold=1, theta=0.1, n_blocks=1
# fold=1, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 5):  44%|████▍     | 28/64 [00:00<00:00, 145.12it/s]
# fold=1, theta=0.2, n_blocks=1
# fold=1, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  38%|███▊      | 24/64 [00:00<00:00, 144.84it/s]
# fold=1, theta=0.3, n_blocks=1
# fold=1, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  27%|██▋       | 17/64 [00:00<00:00, 141.68it/s]
# fold=1, theta=0.4, n_blocks=1
# fold=1, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  20%|██        | 13/64 [00:00<00:00, 139.01it/s]
# fold=1, theta=0.5, n_blocks=1
# fold=1, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  17%|█▋        | 11/64 [00:00<00:00, 136.15it/s]
# fold=1, theta=0.6, n_blocks=1
# fold=1, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 24):  17%|█▋        | 11/64 [00:00<00:00, 135.85it/s]
# fold=1, theta=0.7, n_blocks=1
# fold=1, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  14%|█▍        | 9/64 [00:00<00:00, 134.67it/s]
# fold=1, theta=0.8, n_blocks=1
# fold=1, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(4, 36):  16%|█▌        | 10/64 [00:00<00:00, 134.73it/s]
# fold=1, theta=0.9, n_blocks=1
# fold=1, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.46it/s]
# fold=1, theta=1, n_blocks=1
# fold=2, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  41%|████      | 26/64 [00:00<00:00, 144.06it/s]
# fold=2, theta=0, n_blocks=1
# fold=2, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  44%|████▍     | 28/64 [00:00<00:00, 146.42it/s]
# fold=2, theta=0.1, n_blocks=1
# fold=2, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 5):  31%|███▏      | 20/64 [00:00<00:00, 142.59it/s]
# fold=2, theta=0.2, n_blocks=1
# fold=2, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  28%|██▊       | 18/64 [00:00<00:00, 141.89it/s]
# fold=2, theta=0.3, n_blocks=1
# fold=2, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  23%|██▎       | 15/64 [00:00<00:00, 139.60it/s]
# fold=2, theta=0.4, n_blocks=1
# fold=2, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  20%|██        | 13/64 [00:00<00:00, 138.18it/s]
# fold=2, theta=0.5, n_blocks=1
# fold=2, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  17%|█▋        | 11/64 [00:00<00:00, 135.06it/s]
# fold=2, theta=0.6, n_blocks=1
# fold=2, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 24):  17%|█▋        | 11/64 [00:00<00:00, 135.34it/s]
# fold=2, theta=0.7, n_blocks=1
# fold=2, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  16%|█▌        | 10/64 [00:00<00:00, 136.53it/s]
# fold=2, theta=0.8, n_blocks=1
# fold=2, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(3, 36):  14%|█▍        | 9/64 [00:00<00:00, 134.14it/s]
# fold=2, theta=0.9, n_blocks=1
# fold=2, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.28it/s]
# fold=2, theta=1, n_blocks=1
# fold=3, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  41%|████      | 26/64 [00:00<00:00, 145.56it/s]
# fold=3, theta=0, n_blocks=1
# fold=3, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  52%|█████▏    | 33/64 [00:00<00:00, 147.24it/s]
# fold=3, theta=0.1, n_blocks=1
# fold=3, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4):  48%|████▊     | 31/64 [00:00<00:00, 146.41it/s]
# fold=3, theta=0.2, n_blocks=1
# fold=3, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  38%|███▊      | 24/64 [00:00<00:00, 143.86it/s]
# fold=3, theta=0.3, n_blocks=1
# fold=3, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  27%|██▋       | 17/64 [00:00<00:00, 141.51it/s]
# fold=3, theta=0.4, n_blocks=1
# fold=3, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  20%|██        | 13/64 [00:00<00:00, 138.60it/s]
# fold=3, theta=0.5, n_blocks=1
# fold=3, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 18):  17%|█▋        | 11/64 [00:00<00:00, 134.98it/s]
# fold=3, theta=0.6, n_blocks=1
# fold=3, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 23):  17%|█▋        | 11/64 [00:00<00:00, 135.35it/s]
# fold=3, theta=0.7, n_blocks=1
# fold=3, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  14%|█▍        | 9/64 [00:00<00:00, 133.58it/s]
# fold=3, theta=0.8, n_blocks=1
# fold=3, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(3, 36):  17%|█▋        | 11/64 [00:00<00:00, 137.40it/s]
# fold=3, theta=0.9, n_blocks=1
# fold=3, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.42it/s]
# fold=3, theta=1, n_blocks=1
# fold=4, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  38%|███▊      | 24/64 [00:00<00:00, 144.23it/s]
# fold=4, theta=0, n_blocks=1
# fold=4, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  42%|████▏     | 27/64 [00:00<00:00, 146.38it/s]
# fold=4, theta=0.1, n_blocks=1
# fold=4, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4):  47%|████▋     | 30/64 [00:00<00:00, 147.81it/s]
# fold=4, theta=0.2, n_blocks=1
# fold=4, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  28%|██▊       | 18/64 [00:00<00:00, 142.30it/s]
# fold=4, theta=0.3, n_blocks=1
# fold=4, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  22%|██▏       | 14/64 [00:00<00:00, 137.21it/s]
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    6.7s
# fold=4, theta=0.4, n_blocks=1
# fold=4, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  19%|█▉        | 12/64 [00:00<00:00, 137.28it/s]
# fold=4, theta=0.5, n_blocks=1
# fold=4, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 18):  17%|█▋        | 11/64 [00:00<00:00, 136.01it/s]
# fold=4, theta=0.6, n_blocks=1
# fold=4, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 23):  16%|█▌        | 10/64 [00:00<00:00, 134.54it/s]
# fold=4, theta=0.7, n_blocks=1
# fold=4, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  14%|█▍        | 9/64 [00:00<00:00, 134.94it/s]
# fold=4, theta=0.8, n_blocks=1
# fold=4, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(4, 36):  17%|█▋        | 11/64 [00:00<00:00, 137.65it/s]
# fold=4, theta=0.9, n_blocks=1
# fold=4, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.46it/s]
# fold=4, theta=1, n_blocks=1
# Fitting BTTDA with theta=1.0, n_blocks=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:01, 60.99it/s]
# Forward model :   0%|          | 0/63 [00:00<?, ?it/s]
# fold=0, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  39%|███▉      | 25/64 [00:00<00:00, 144.78it/s]
# fold=0, theta=0, n_blocks=1
# fold=0, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  39%|███▉      | 25/64 [00:00<00:00, 145.56it/s]
# fold=0, theta=0.1, n_blocks=1
# fold=0, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4):  34%|███▍      | 22/64 [00:00<00:00, 144.41it/s]
# fold=0, theta=0.2, n_blocks=1
# fold=0, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  25%|██▌       | 16/64 [00:00<00:00, 141.66it/s]
# fold=0, theta=0.3, n_blocks=1
# fold=0, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  20%|██        | 13/64 [00:00<00:00, 138.97it/s]
# fold=0, theta=0.4, n_blocks=1
# fold=0, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  17%|█▋        | 11/64 [00:00<00:00, 136.38it/s]
# fold=0, theta=0.5, n_blocks=1
# fold=0, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 18):  16%|█▌        | 10/64 [00:00<00:00, 134.40it/s]
# fold=0, theta=0.6, n_blocks=1
# fold=0, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 23):  14%|█▍        | 9/64 [00:00<00:00, 132.80it/s]
# fold=0, theta=0.7, n_blocks=1
# fold=0, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  12%|█▎        | 8/64 [00:00<00:00, 132.62it/s]
# fold=0, theta=0.8, n_blocks=1
# fold=0, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(4, 36):  20%|██        | 13/64 [00:00<00:00, 137.47it/s]
# fold=0, theta=0.9, n_blocks=1
# fold=0, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 63.95it/s]
# fold=0, theta=1, n_blocks=1
# fold=1, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  88%|████████▊ | 56/64 [00:00<00:00, 149.27it/s]
# fold=1, theta=0, n_blocks=1
# fold=1, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  69%|██████▉   | 44/64 [00:00<00:00, 149.22it/s]
# fold=1, theta=0.1, n_blocks=1
# fold=1, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 5):  47%|████▋     | 30/64 [00:00<00:00, 146.66it/s]
# fold=1, theta=0.2, n_blocks=1
# fold=1, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  31%|███▏      | 20/64 [00:00<00:00, 144.45it/s]
# fold=1, theta=0.3, n_blocks=1
# fold=1, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  22%|██▏       | 14/64 [00:00<00:00, 140.86it/s]
# fold=1, theta=0.4, n_blocks=1
# fold=1, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  17%|█▋        | 11/64 [00:00<00:00, 135.11it/s]
# fold=1, theta=0.5, n_blocks=1
# fold=1, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  17%|█▋        | 11/64 [00:00<00:00, 135.81it/s]
# fold=1, theta=0.6, n_blocks=1
# fold=1, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 24):  17%|█▋        | 11/64 [00:00<00:00, 136.22it/s]
# fold=1, theta=0.7, n_blocks=1
# fold=1, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  14%|█▍        | 9/64 [00:00<00:00, 135.07it/s]
# fold=1, theta=0.8, n_blocks=1
# fold=1, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(4, 36):  42%|████▏     | 27/64 [00:00<00:00, 147.20it/s]
# fold=1, theta=0.9, n_blocks=1
# fold=1, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.68it/s]
# fold=1, theta=1, n_blocks=1
# fold=2, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  42%|████▏     | 27/64 [00:00<00:00, 146.19it/s]
# fold=2, theta=0, n_blocks=1
# fold=2, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  56%|█████▋    | 36/64 [00:00<00:00, 147.96it/s]
# fold=2, theta=0.1, n_blocks=1
# fold=2, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 5):  38%|███▊      | 24/64 [00:00<00:00, 145.07it/s]
# fold=2, theta=0.2, n_blocks=1
# fold=2, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 8):  27%|██▋       | 17/64 [00:00<00:00, 142.23it/s]
# fold=2, theta=0.3, n_blocks=1
# fold=2, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 11):  19%|█▉        | 12/64 [00:00<00:00, 138.77it/s]
# fold=2, theta=0.4, n_blocks=1
# fold=2, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 15):  20%|██        | 13/64 [00:00<00:00, 139.49it/s]
# fold=2, theta=0.5, n_blocks=1
# fold=2, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  19%|█▉        | 12/64 [00:00<00:00, 137.75it/s]
# fold=2, theta=0.6, n_blocks=1
# fold=2, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 24):  19%|█▉        | 12/64 [00:00<00:00, 137.42it/s]
# fold=2, theta=0.7, n_blocks=1
# fold=2, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 30):  16%|█▌        | 10/64 [00:00<00:00, 136.47it/s]
# fold=2, theta=0.8, n_blocks=1
# fold=2, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(3, 36):  22%|██▏       | 14/64 [00:00<00:00, 141.23it/s]
# fold=2, theta=0.9, n_blocks=1
# fold=2, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.14it/s]
# fold=2, theta=1, n_blocks=1
# fold=3, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  42%|████▏     | 27/64 [00:00<00:00, 146.07it/s]
# fold=3, theta=0, n_blocks=1
# fold=3, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  53%|█████▎    | 34/64 [00:00<00:00, 147.44it/s]
# fold=3, theta=0.1, n_blocks=1
# fold=3, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4):  52%|█████▏    | 33/64 [00:00<00:00, 147.49it/s]
# fold=3, theta=0.2, n_blocks=1
# fold=3, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  31%|███▏      | 20/64 [00:00<00:00, 144.09it/s]
# fold=3, theta=0.3, n_blocks=1
# fold=3, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  22%|██▏       | 14/64 [00:00<00:00, 139.80it/s]
# fold=3, theta=0.4, n_blocks=1
# fold=3, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  17%|█▋        | 11/64 [00:00<00:00, 136.53it/s]
# fold=3, theta=0.5, n_blocks=1
# fold=3, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  17%|█▋        | 11/64 [00:00<00:00, 136.40it/s]
# fold=3, theta=0.6, n_blocks=1
# fold=3, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 24):  17%|█▋        | 11/64 [00:00<00:00, 137.13it/s]
# fold=3, theta=0.7, n_blocks=1
# fold=3, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  14%|█▍        | 9/64 [00:00<00:00, 134.39it/s]
# fold=3, theta=0.8, n_blocks=1
# fold=3, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(3, 36):  16%|█▌        | 10/64 [00:00<00:00, 136.65it/s]
# fold=3, theta=0.9, n_blocks=1
# fold=3, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.77it/s]
# fold=3, theta=1, n_blocks=1
# fold=4, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  33%|███▎      | 21/64 [00:00<00:00, 144.69it/s]
# fold=4, theta=0, n_blocks=1
# fold=4, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  44%|████▍     | 28/64 [00:00<00:00, 147.70it/s]
# fold=4, theta=0.1, n_blocks=1
# fold=4, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4):  33%|███▎      | 21/64 [00:00<00:00, 145.52it/s]
# fold=4, theta=0.2, n_blocks=1
# fold=4, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  25%|██▌       | 16/64 [00:00<00:00, 142.74it/s]
# fold=4, theta=0.3, n_blocks=1
# fold=4, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 11):  19%|█▉        | 12/64 [00:00<00:00, 138.65it/s]
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    6.9s
# fold=4, theta=0.4, n_blocks=1
# fold=4, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  17%|█▋        | 11/64 [00:00<00:00, 137.59it/s]
# fold=4, theta=0.5, n_blocks=1
# fold=4, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  17%|█▋        | 11/64 [00:00<00:00, 136.51it/s]
# fold=4, theta=0.6, n_blocks=1
# fold=4, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 24):  16%|█▌        | 10/64 [00:00<00:00, 134.88it/s]
# fold=4, theta=0.7, n_blocks=1
# fold=4, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  14%|█▍        | 9/64 [00:00<00:00, 135.12it/s]
# fold=4, theta=0.8, n_blocks=1
# fold=4, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(4, 36):  19%|█▉        | 12/64 [00:00<00:00, 138.65it/s]
# fold=4, theta=0.9, n_blocks=1
# fold=4, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.69it/s]
# fold=4, theta=1, n_blocks=1
# Fitting BTTDA with theta=1.0, n_blocks=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:01, 61.07it/s]
# Forward model :   0%|          | 0/63 [00:00<?, ?it/s]
# fold=0, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  34%|███▍      | 22/64 [00:00<00:00, 144.04it/s]
# fold=0, theta=0, n_blocks=1
# fold=0, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  38%|███▊      | 24/64 [00:00<00:00, 146.06it/s]
# fold=0, theta=0.1, n_blocks=1
# fold=0, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4):  39%|███▉      | 25/64 [00:00<00:00, 146.28it/s]
# fold=0, theta=0.2, n_blocks=1
# fold=0, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  28%|██▊       | 18/64 [00:00<00:00, 143.53it/s]
# fold=0, theta=0.3, n_blocks=1
# fold=0, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  22%|██▏       | 14/64 [00:00<00:00, 137.59it/s]
# fold=0, theta=0.4, n_blocks=1
# fold=0, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 13):  19%|█▉        | 12/64 [00:00<00:00, 136.44it/s]
# fold=0, theta=0.5, n_blocks=1
# fold=0, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 18):  16%|█▌        | 10/64 [00:00<00:00, 134.63it/s]
# fold=0, theta=0.6, n_blocks=1
# fold=0, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 23):  16%|█▌        | 10/64 [00:00<00:00, 134.50it/s]
# fold=0, theta=0.7, n_blocks=1
# fold=0, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  12%|█▎        | 8/64 [00:00<00:00, 132.89it/s]
# fold=0, theta=0.8, n_blocks=1
# fold=0, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(4, 36):  19%|█▉        | 12/64 [00:00<00:00, 138.97it/s]
# fold=0, theta=0.9, n_blocks=1
# fold=0, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.36it/s]
# fold=0, theta=1, n_blocks=1
# fold=1, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1): 100%|██████████| 64/64 [00:00<00:00, 152.30it/s]
# /vsc-hard-mounts/leuven-data/352/vsc35289/hoda-bci/src/hoda/hoda.py:358: UserWarning:
#
# Maximum number of iterations reached without convergence
# fold=1, theta=0, n_blocks=1
# fold=1, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  95%|█████████▌| 61/64 [00:00<00:00, 150.86it/s]
# fold=1, theta=0.1, n_blocks=1
# fold=1, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 5):  50%|█████     | 32/64 [00:00<00:00, 147.58it/s]
# fold=1, theta=0.2, n_blocks=1
# fold=1, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  34%|███▍      | 22/64 [00:00<00:00, 145.64it/s]
# fold=1, theta=0.3, n_blocks=1
# fold=1, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 11):  20%|██        | 13/64 [00:00<00:00, 139.97it/s]
# fold=1, theta=0.4, n_blocks=1
# fold=1, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  19%|█▉        | 12/64 [00:00<00:00, 138.82it/s]
# fold=1, theta=0.5, n_blocks=1
# fold=1, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  17%|█▋        | 11/64 [00:00<00:00, 136.33it/s]
# fold=1, theta=0.6, n_blocks=1
# fold=1, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 24):  17%|█▋        | 11/64 [00:00<00:00, 136.43it/s]
# fold=1, theta=0.7, n_blocks=1
# fold=1, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  14%|█▍        | 9/64 [00:00<00:00, 135.29it/s]
# fold=1, theta=0.8, n_blocks=1
# fold=1, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(4, 36):  28%|██▊       | 18/64 [00:00<00:00, 142.68it/s]
# fold=1, theta=0.9, n_blocks=1
# fold=1, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.25it/s]
# fold=1, theta=1, n_blocks=1
# fold=2, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  52%|█████▏    | 33/64 [00:00<00:00, 147.58it/s]
# fold=2, theta=0, n_blocks=1
# fold=2, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  78%|███████▊  | 50/64 [00:00<00:00, 150.55it/s]
# fold=2, theta=0.1, n_blocks=1
# fold=2, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 5):  36%|███▌      | 23/64 [00:00<00:00, 145.22it/s]
# fold=2, theta=0.2, n_blocks=1
# fold=2, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  30%|██▉       | 19/64 [00:00<00:00, 143.20it/s]
# fold=2, theta=0.3, n_blocks=1
# fold=2, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 11):  20%|██        | 13/64 [00:00<00:00, 138.80it/s]
# fold=2, theta=0.4, n_blocks=1
# fold=2, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  20%|██        | 13/64 [00:00<00:00, 139.15it/s]
# fold=2, theta=0.5, n_blocks=1
# fold=2, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  20%|██        | 13/64 [00:00<00:00, 138.09it/s]
# fold=2, theta=0.6, n_blocks=1
# fold=2, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 24):  19%|█▉        | 12/64 [00:00<00:00, 137.55it/s]
# fold=2, theta=0.7, n_blocks=1
# fold=2, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  16%|█▌        | 10/64 [00:00<00:00, 136.66it/s]
# fold=2, theta=0.8, n_blocks=1
# fold=2, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(3, 36):  19%|█▉        | 12/64 [00:00<00:00, 138.57it/s]
# fold=2, theta=0.9, n_blocks=1
# fold=2, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.24it/s]
# fold=2, theta=1, n_blocks=1
# fold=3, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  45%|████▌     | 29/64 [00:00<00:00, 146.69it/s]
# fold=3, theta=0, n_blocks=1
# fold=3, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  55%|█████▍    | 35/64 [00:00<00:00, 147.68it/s]
# fold=3, theta=0.1, n_blocks=1
# fold=3, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4):  53%|█████▎    | 34/64 [00:00<00:00, 147.94it/s]
# fold=3, theta=0.2, n_blocks=1
# fold=3, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  33%|███▎      | 21/64 [00:00<00:00, 144.21it/s]
# fold=3, theta=0.3, n_blocks=1
# fold=3, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  22%|██▏       | 14/64 [00:00<00:00, 140.32it/s]
# fold=3, theta=0.4, n_blocks=1
# fold=3, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  19%|█▉        | 12/64 [00:00<00:00, 137.00it/s]
# fold=3, theta=0.5, n_blocks=1
# fold=3, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 18):  17%|█▋        | 11/64 [00:00<00:00, 135.46it/s]
# fold=3, theta=0.6, n_blocks=1
# fold=3, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 23):  17%|█▋        | 11/64 [00:00<00:00, 133.53it/s]
# fold=3, theta=0.7, n_blocks=1
# fold=3, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  17%|█▋        | 11/64 [00:00<00:00, 137.84it/s]
# fold=3, theta=0.8, n_blocks=1
# fold=3, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(3, 36):  14%|█▍        | 9/64 [00:00<00:00, 134.16it/s]
# fold=3, theta=0.9, n_blocks=1
# fold=3, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.56it/s]
# fold=3, theta=1, n_blocks=1
# fold=4, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  45%|████▌     | 29/64 [00:00<00:00, 145.56it/s]
# fold=4, theta=0, n_blocks=1
# fold=4, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  56%|█████▋    | 36/64 [00:00<00:00, 148.26it/s]
# fold=4, theta=0.1, n_blocks=1
# fold=4, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4):  50%|█████     | 32/64 [00:00<00:00, 145.68it/s]
# fold=4, theta=0.2, n_blocks=1
# fold=4, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  30%|██▉       | 19/64 [00:00<00:00, 143.72it/s]
# fold=4, theta=0.3, n_blocks=1
# fold=4, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  22%|██▏       | 14/64 [00:00<00:00, 140.81it/s]
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    7.5s
# fold=4, theta=0.4, n_blocks=1
# fold=4, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  19%|█▉        | 12/64 [00:00<00:00, 136.24it/s]
# fold=4, theta=0.5, n_blocks=1
# fold=4, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  17%|█▋        | 11/64 [00:00<00:00, 131.46it/s]
# fold=4, theta=0.6, n_blocks=1
# fold=4, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 23):  16%|█▌        | 10/64 [00:00<00:00, 132.10it/s]
# fold=4, theta=0.7, n_blocks=1
# fold=4, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  14%|█▍        | 9/64 [00:00<00:00, 131.99it/s]
# fold=4, theta=0.8, n_blocks=1
# fold=4, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(3, 36):  16%|█▌        | 10/64 [00:00<00:00, 134.59it/s]
# fold=4, theta=0.9, n_blocks=1
# fold=4, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.41it/s]
# fold=4, theta=1, n_blocks=1
# Fitting BTTDA with theta=1.0, n_blocks=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:01, 61.57it/s]
# Forward model :   0%|          | 0/63 [00:00<?, ?it/s]
# fold=0, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  44%|████▍     | 28/64 [00:00<00:00, 144.38it/s]
# fold=0, theta=0, n_blocks=1
# fold=0, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  45%|████▌     | 29/64 [00:00<00:00, 145.00it/s]
# fold=0, theta=0.1, n_blocks=1
# fold=0, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4):  42%|████▏     | 27/64 [00:00<00:00, 144.02it/s]
# fold=0, theta=0.2, n_blocks=1
# fold=0, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  34%|███▍      | 22/64 [00:00<00:00, 142.52it/s]
# fold=0, theta=0.3, n_blocks=1
# fold=0, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  25%|██▌       | 16/64 [00:00<00:00, 139.96it/s]
# fold=0, theta=0.4, n_blocks=1
# fold=0, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  20%|██        | 13/64 [00:00<00:00, 137.29it/s]
# fold=0, theta=0.5, n_blocks=1
# fold=0, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 18):  19%|█▉        | 12/64 [00:00<00:00, 136.26it/s]
# fold=0, theta=0.6, n_blocks=1
# fold=0, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 23):  19%|█▉        | 12/64 [00:00<00:00, 136.82it/s]
# fold=0, theta=0.7, n_blocks=1
# fold=0, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  14%|█▍        | 9/64 [00:00<00:00, 134.13it/s]
# fold=0, theta=0.8, n_blocks=1
# fold=0, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(4, 36):  12%|█▎        | 8/64 [00:00<00:00, 131.28it/s]
# fold=0, theta=0.9, n_blocks=1
# fold=0, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.18it/s]
# fold=0, theta=1, n_blocks=1
# fold=1, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  59%|█████▉    | 38/64 [00:00<00:00, 147.02it/s]
# fold=1, theta=0, n_blocks=1
# fold=1, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  50%|█████     | 32/64 [00:00<00:00, 146.89it/s]
# fold=1, theta=0.1, n_blocks=1
# fold=1, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 5):  50%|█████     | 32/64 [00:00<00:00, 147.12it/s]
# fold=1, theta=0.2, n_blocks=1
# fold=1, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  38%|███▊      | 24/64 [00:00<00:00, 145.36it/s]
# fold=1, theta=0.3, n_blocks=1
# fold=1, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 11):  22%|██▏       | 14/64 [00:00<00:00, 139.78it/s]
# fold=1, theta=0.4, n_blocks=1
# fold=1, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  19%|█▉        | 12/64 [00:00<00:00, 136.71it/s]
# fold=1, theta=0.5, n_blocks=1
# fold=1, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  17%|█▋        | 11/64 [00:00<00:00, 134.91it/s]
# fold=1, theta=0.6, n_blocks=1
# fold=1, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 24):  17%|█▋        | 11/64 [00:00<00:00, 134.88it/s]
# fold=1, theta=0.7, n_blocks=1
# fold=1, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  14%|█▍        | 9/64 [00:00<00:00, 134.55it/s]
# fold=1, theta=0.8, n_blocks=1
# fold=1, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(4, 36):  14%|█▍        | 9/64 [00:00<00:00, 134.09it/s]
# fold=1, theta=0.9, n_blocks=1
# fold=1, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 64.11it/s]
# fold=1, theta=1, n_blocks=1
# fold=2, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  41%|████      | 26/64 [00:00<00:00, 144.52it/s]
# fold=2, theta=0, n_blocks=1
# fold=2, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  50%|█████     | 32/64 [00:00<00:00, 145.10it/s]
# fold=2, theta=0.1, n_blocks=1
# fold=2, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 5):  42%|████▏     | 27/64 [00:00<00:00, 144.31it/s]
# fold=2, theta=0.2, n_blocks=1
# fold=2, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 8):  31%|███▏      | 20/64 [00:00<00:00, 142.59it/s]
# fold=2, theta=0.3, n_blocks=1
# fold=2, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 11):  22%|██▏       | 14/64 [00:00<00:00, 139.23it/s]
# fold=2, theta=0.4, n_blocks=1
# fold=2, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 15):  20%|██        | 13/64 [00:00<00:00, 136.67it/s]
# fold=2, theta=0.5, n_blocks=1
# fold=2, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  20%|██        | 13/64 [00:00<00:00, 137.50it/s]
# fold=2, theta=0.6, n_blocks=1
# fold=2, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 24):  19%|█▉        | 12/64 [00:00<00:00, 135.01it/s]
# fold=2, theta=0.7, n_blocks=1
# fold=2, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 30):  17%|█▋        | 11/64 [00:00<00:00, 137.02it/s]
# fold=2, theta=0.8, n_blocks=1
# fold=2, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(3, 36):  20%|██        | 13/64 [00:00<00:00, 136.41it/s]
# fold=2, theta=0.9, n_blocks=1
# fold=2, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 63.69it/s]
# fold=2, theta=1, n_blocks=1
# fold=3, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  41%|████      | 26/64 [00:00<00:00, 142.73it/s]
# fold=3, theta=0, n_blocks=1
# fold=3, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  77%|███████▋  | 49/64 [00:00<00:00, 144.49it/s]
# fold=3, theta=0.1, n_blocks=1
# fold=3, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 4):  62%|██████▎   | 40/64 [00:00<00:00, 144.54it/s]
# fold=3, theta=0.2, n_blocks=1
# fold=3, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  45%|████▌     | 29/64 [00:00<00:00, 145.62it/s]
# fold=3, theta=0.3, n_blocks=1
# fold=3, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 10):  28%|██▊       | 18/64 [00:00<00:00, 141.60it/s]
# fold=3, theta=0.4, n_blocks=1
# fold=3, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  19%|█▉        | 12/64 [00:00<00:00, 137.22it/s]
# fold=3, theta=0.5, n_blocks=1
# fold=3, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  17%|█▋        | 11/64 [00:00<00:00, 134.74it/s]
# fold=3, theta=0.6, n_blocks=1
# fold=3, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 23):  17%|█▋        | 11/64 [00:00<00:00, 134.48it/s]
# fold=3, theta=0.7, n_blocks=1
# fold=3, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  16%|█▌        | 10/64 [00:00<00:00, 135.31it/s]
# fold=3, theta=0.8, n_blocks=1
# fold=3, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(3, 36):  16%|█▌        | 10/64 [00:00<00:00, 134.47it/s]
# fold=3, theta=0.9, n_blocks=1
# fold=3, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 63.90it/s]
# fold=3, theta=1, n_blocks=1
# fold=4, theta=0
# Fitting block 1/1...
# Backward HODA model rank=(1, 1):  52%|█████▏    | 33/64 [00:00<00:00, 143.99it/s]
# fold=4, theta=0, n_blocks=1
# fold=4, theta=0.1
# Fitting block 1/1...
# Backward HODA model rank=(1, 2):  47%|████▋     | 30/64 [00:00<00:00, 145.50it/s]
# fold=4, theta=0.1, n_blocks=1
# fold=4, theta=0.2
# Fitting block 1/1...
# Backward HODA model rank=(1, 5):  50%|█████     | 32/64 [00:00<00:00, 145.31it/s]
# fold=4, theta=0.2, n_blocks=1
# fold=4, theta=0.3
# Fitting block 1/1...
# Backward HODA model rank=(1, 7):  38%|███▊      | 24/64 [00:00<00:00, 143.61it/s]
# fold=4, theta=0.3, n_blocks=1
# fold=4, theta=0.4
# Fitting block 1/1...
# Backward HODA model rank=(1, 11):  23%|██▎       | 15/64 [00:00<00:00, 139.29it/s]
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    7.4s
# fold=4, theta=0.4, n_blocks=1
# fold=4, theta=0.5
# Fitting block 1/1...
# Backward HODA model rank=(1, 14):  20%|██        | 13/64 [00:00<00:00, 137.16it/s]
# fold=4, theta=0.5, n_blocks=1
# fold=4, theta=0.6
# Fitting block 1/1...
# Backward HODA model rank=(1, 19):  17%|█▋        | 11/64 [00:00<00:00, 134.16it/s]
# fold=4, theta=0.6, n_blocks=1
# fold=4, theta=0.7
# Fitting block 1/1...
# Backward HODA model rank=(1, 24):  16%|█▌        | 10/64 [00:00<00:00, 133.08it/s]
# fold=4, theta=0.7, n_blocks=1
# fold=4, theta=0.8
# Fitting block 1/1...
# Backward HODA model rank=(2, 29):  12%|█▎        | 8/64 [00:00<00:00, 130.89it/s]
# fold=4, theta=0.8, n_blocks=1
# fold=4, theta=0.9
# Fitting block 1/1...
# Backward HODA model rank=(4, 36):  23%|██▎       | 15/64 [00:00<00:00, 139.28it/s]
# fold=4, theta=0.9, n_blocks=1
# fold=4, theta=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:00, 63.48it/s]
# fold=4, theta=1, n_blocks=1
# Fitting BTTDA with theta=1.0, n_blocks=1
# Fitting block 1/1...
# Backward HODA model rank=(8, 48):   2%|▏         | 1/64 [00:00<00:01, 60.83it/s]
# Forward model :   0%|          | 0/63 [00:00<?, ?it/s]
# BNCI2014-008-WithinSession: 100%|██████████| 1/1 [00:45<00:00, 45.48s/it]
