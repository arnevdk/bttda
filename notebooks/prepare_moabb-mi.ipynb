# %%
from moabb.paradigms import FilterBankMotorImagery
from moabb.datasets import *

paradigm = FilterBankMotorImagery(resample=250)
datasets = paradigm.datasets
exclude = [
    "MNE_DATASETS_FAKEVIRTUALREALITYDATASET-P300-21-1--60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60--120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120--TARGET-NONTARGET--C3-CZ-C4",
    "Schirrmeister2017",
    "Stieger2021",
    # Download locally
    "BNCI2014-001",
    "BNCI2014-002",
    "BNCI2014-004",
    "BNCI2015-001",
    "BNCI2015-004",

]
datasets = [d for d in datasets if d.code not in exclude and not d.code.startswith('Fake')]
for dataset in datasets:
    print(dataset.code)
# Out:
# Choosing from all possible events
# AlexandreMotorImagery
# Cho2017
# GrosseWentrup2009
# Lee2019-MI
# Liu2024
# Ofner2017
# PhysionetMotorImagery
# Shin2017A
# Weibo2014
# Zhou2016

# %%
# %load_ext autoreload
# %autoreload 2

# %%
cache_config = dict(
    use=True,
    save_raw=False,
    save_epochs=False,
    save_array=True,
    overwrite_raw=False,
    overwrite_epochs=False,
    overwrite_array=False,
)
for dataset in datasets:
    print(f'dataset: {dataset.code}, classes: {dataset.event_id}')
    n_subjects = len(dataset.subject_list)
    paradigm = FilterBankMotorImagery(n_classes=len(dataset.event_id),resample=250)    
    for subject in dataset.subject_list:
        print(f'Processing {dataset.code} subject {subject}/{n_subjects} ...')
        X,y,meta = paradigm.get_data(dataset, subjects=[subject], cache_config=cache_config)
# Out:
# Choosing from all possible events
# dataset: AlexandreMotorImagery, classes: {'right_hand': 2, 'feet': 3, 'rest': 4}
# Processing AlexandreMotorImagery subject 1/8 ...
# Processing AlexandreMotorImagery subject 2/8 ...
# /data/leuven/352/vsc35289/miniconda3/envs/bttda-cuda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 60 events (all good), 0 – 3 s (baseline off), ~11.3 MiB, data loaded,
#  'right_hand': 20
#  'feet': 20
#  'rest': 20>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-alexandre-motor-imagery/dataset_description.json'...
# /data/leuven/352/vsc35289/miniconda3/envs/bttda-cuda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 60 events (all good), 0 – 3 s (baseline off), ~11.3 MiB, data loaded,
#  'right_hand': 20
#  'feet': 20
#  'rest': 20>
#   warn(f"warnEpochs {epochs}")
# ...
