# %%
from moabb.paradigms import P300
from moabb.datasets import *

paradigm = P300(resample=48)
datasets = paradigm.datasets
exclude = [
    # Did not download
    'EPFLP300',
    'ErpCore2021-N2pc',
    'Sosulski2019',
    'Huebner2017',
    'Huebner2018',
    # Not included
    'DemonsP300',
    'FakeVirtualRealityDataset-p300-21-1--60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60--120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120--target-nontarget--c3-cz-c4',

]
datasets = [d for d in datasets if d.code not in exclude and not d.code.startswith('Fake')]
for dataset in datasets:
    print(dataset.code)
# Out:
# BrainInvaders2012
# BrainInvaders2013a
# BrainInvaders2014a
# BrainInvaders2014b
# BrainInvaders2015a
# BrainInvaders2015b
# BNCI2014-008
# BNCI2014-009
# BNCI2015-003
# Cattan2019-VR
# ErpCore2021-ERN
# ErpCore2021-LRP
# ErpCore2021-MMN
# ErpCore2021-N170
# ErpCore2021-N400
# ErpCore2021-P3
# Lee2019-ERP

# %%
for dataset in datasets:
    print(dataset.code)
    dataset.download(verbose=True, accept=True)
# Out:
# Huebner2017

# %%
cache_config = dict(
    use=True,
    save_raw=False,
    save_epochs=False,
    save_array=True,
    overwrite_raw=False,
    overwrite_epochs=False,
    overwrite_array=False,
)
for dataset in datasets:
    n_subjects = len(dataset.subject_list)
    for subject in dataset.subject_list:
        print(f'Processing {dataset.code} subject {subject}/{n_subjects} ...')
        paradigm.get_data(dataset, subjects=[subject], cache_config=cache_config)
    print()
# Out:
# Processing BrainInvaders2012 subject 1/25 ...
# Processing BrainInvaders2012 subject 2/25 ...
# Processing BrainInvaders2012 subject 3/25 ...
# Processing BrainInvaders2012 subject 4/25 ...
# Processing BrainInvaders2012 subject 5/25 ...
# Processing BrainInvaders2012 subject 6/25 ...
# Processing BrainInvaders2012 subject 7/25 ...
# Processing BrainInvaders2012 subject 8/25 ...
# Processing BrainInvaders2012 subject 9/25 ...
# Processing BrainInvaders2012 subject 10/25 ...
# Processing BrainInvaders2012 subject 11/25 ...
# Processing BrainInvaders2012 subject 12/25 ...
# Processing BrainInvaders2012 subject 13/25 ...
# Processing BrainInvaders2012 subject 14/25 ...
# Processing BrainInvaders2012 subject 15/25 ...
# Processing BrainInvaders2012 subject 16/25 ...
# Processing BrainInvaders2012 subject 17/25 ...
# Processing BrainInvaders2012 subject 18/25 ...
# Processing BrainInvaders2012 subject 19/25 ...
# Processing BrainInvaders2012 subject 20/25 ...
# Processing BrainInvaders2012 subject 21/25 ...
# Processing BrainInvaders2012 subject 22/25 ...
# Processing BrainInvaders2012 subject 23/25 ...
# Processing BrainInvaders2012 subject 24/25 ...
# Processing BrainInvaders2012 subject 25/25 ...
#
# Processing BrainInvaders2013a subject 1/24 ...
# Processing BrainInvaders2013a subject 2/24 ...
# Processing BrainInvaders2013a subject 3/24 ...
# Processing BrainInvaders2013a subject 4/24 ...
# Processing BrainInvaders2013a subject 5/24 ...
# Processing BrainInvaders2013a subject 6/24 ...
# Processing BrainInvaders2013a subject 7/24 ...
# Processing BrainInvaders2013a subject 8/24 ...
# Processing BrainInvaders2013a subject 9/24 ...
# Processing BrainInvaders2013a subject 10/24 ...
# Processing BrainInvaders2013a subject 11/24 ...
# Processing BrainInvaders2013a subject 12/24 ...
# Processing BrainInvaders2013a subject 13/24 ...
# Processing BrainInvaders2013a subject 14/24 ...
# Processing BrainInvaders2013a subject 15/24 ...
# Processing BrainInvaders2013a subject 16/24 ...
# Processing BrainInvaders2013a subject 17/24 ...
# Processing BrainInvaders2013a subject 18/24 ...
# Processing BrainInvaders2013a subject 19/24 ...
# Processing BrainInvaders2013a subject 20/24 ...
# Processing BrainInvaders2013a subject 21/24 ...
# Processing BrainInvaders2013a subject 22/24 ...
# Processing BrainInvaders2013a subject 23/24 ...
# Processing BrainInvaders2013a subject 24/24 ...
#
# Processing BrainInvaders2014a subject 1/64 ...
# Processing BrainInvaders2014a subject 2/64 ...
# Processing BrainInvaders2014a subject 3/64 ...
# Processing BrainInvaders2014a subject 4/64 ...
# Processing BrainInvaders2014a subject 5/64 ...
# Processing BrainInvaders2014a subject 6/64 ...
# Processing BrainInvaders2014a subject 7/64 ...
# Processing BrainInvaders2014a subject 8/64 ...
# Processing BrainInvaders2014a subject 9/64 ...
# Processing BrainInvaders2014a subject 10/64 ...
# Processing BrainInvaders2014a subject 11/64 ...
# Processing BrainInvaders2014a subject 12/64 ...
# Processing BrainInvaders2014a subject 13/64 ...
# Processing BrainInvaders2014a subject 14/64 ...
# Processing BrainInvaders2014a subject 15/64 ...
# Processing BrainInvaders2014a subject 16/64 ...
# Processing BrainInvaders2014a subject 17/64 ...
# Processing BrainInvaders2014a subject 18/64 ...
# Processing BrainInvaders2014a subject 19/64 ...
# Processing BrainInvaders2014a subject 20/64 ...
# Processing BrainInvaders2014a subject 21/64 ...
# Processing BrainInvaders2014a subject 22/64 ...
# Processing BrainInvaders2014a subject 23/64 ...
# Processing BrainInvaders2014a subject 24/64 ...
# Processing BrainInvaders2014a subject 25/64 ...
# Processing BrainInvaders2014a subject 26/64 ...
# Processing BrainInvaders2014a subject 27/64 ...
# Processing BrainInvaders2014a subject 28/64 ...
# Processing BrainInvaders2014a subject 29/64 ...
# Processing BrainInvaders2014a subject 30/64 ...
# Processing BrainInvaders2014a subject 31/64 ...
# Processing BrainInvaders2014a subject 32/64 ...
# Processing BrainInvaders2014a subject 33/64 ...
# Processing BrainInvaders2014a subject 34/64 ...
# Processing BrainInvaders2014a subject 35/64 ...
# Processing BrainInvaders2014a subject 36/64 ...
# Processing BrainInvaders2014a subject 37/64 ...
# Processing BrainInvaders2014a subject 38/64 ...
# Processing BrainInvaders2014a subject 39/64 ...
# Processing BrainInvaders2014a subject 40/64 ...
# Processing BrainInvaders2014a subject 41/64 ...
# Processing BrainInvaders2014a subject 42/64 ...
# Processing BrainInvaders2014a subject 43/64 ...
# Processing BrainInvaders2014a subject 44/64 ...
# Processing BrainInvaders2014a subject 45/64 ...
# Processing BrainInvaders2014a subject 46/64 ...
# Processing BrainInvaders2014a subject 47/64 ...
# Processing BrainInvaders2014a subject 48/64 ...
# Processing BrainInvaders2014a subject 49/64 ...
# Processing BrainInvaders2014a subject 50/64 ...
# Processing BrainInvaders2014a subject 51/64 ...
# Processing BrainInvaders2014a subject 52/64 ...
# Processing BrainInvaders2014a subject 53/64 ...
# Processing BrainInvaders2014a subject 54/64 ...
# Processing BrainInvaders2014a subject 55/64 ...
# Processing BrainInvaders2014a subject 56/64 ...
# Processing BrainInvaders2014a subject 57/64 ...
# Processing BrainInvaders2014a subject 58/64 ...
# Processing BrainInvaders2014a subject 59/64 ...
# Processing BrainInvaders2014a subject 60/64 ...
# Processing BrainInvaders2014a subject 61/64 ...
# Processing BrainInvaders2014a subject 62/64 ...
# Processing BrainInvaders2014a subject 63/64 ...
# Processing BrainInvaders2014a subject 64/64 ...
#
# Processing BrainInvaders2014b subject 1/38 ...
# Processing BrainInvaders2014b subject 2/38 ...
# Processing BrainInvaders2014b subject 3/38 ...
# Processing BrainInvaders2014b subject 4/38 ...
# Processing BrainInvaders2014b subject 5/38 ...
# Processing BrainInvaders2014b subject 6/38 ...
# Processing BrainInvaders2014b subject 7/38 ...
# Processing BrainInvaders2014b subject 8/38 ...
# Processing BrainInvaders2014b subject 9/38 ...
# Processing BrainInvaders2014b subject 10/38 ...
# Processing BrainInvaders2014b subject 11/38 ...
# Processing BrainInvaders2014b subject 12/38 ...
# Processing BrainInvaders2014b subject 13/38 ...
# Processing BrainInvaders2014b subject 14/38 ...
# Processing BrainInvaders2014b subject 15/38 ...
# Processing BrainInvaders2014b subject 16/38 ...
# Processing BrainInvaders2014b subject 17/38 ...
# Processing BrainInvaders2014b subject 18/38 ...
# Processing BrainInvaders2014b subject 19/38 ...
# Processing BrainInvaders2014b subject 20/38 ...
# Processing BrainInvaders2014b subject 21/38 ...
# Processing BrainInvaders2014b subject 22/38 ...
# Processing BrainInvaders2014b subject 23/38 ...
# Processing BrainInvaders2014b subject 24/38 ...
# Processing BrainInvaders2014b subject 25/38 ...
# Processing BrainInvaders2014b subject 26/38 ...
# Processing BrainInvaders2014b subject 27/38 ...
# Processing BrainInvaders2014b subject 28/38 ...
# Processing BrainInvaders2014b subject 29/38 ...
# Processing BrainInvaders2014b subject 30/38 ...
# Processing BrainInvaders2014b subject 31/38 ...
# Processing BrainInvaders2014b subject 32/38 ...
# Processing BrainInvaders2014b subject 33/38 ...
# Processing BrainInvaders2014b subject 34/38 ...
# Processing BrainInvaders2014b subject 35/38 ...
# Processing BrainInvaders2014b subject 36/38 ...
# Processing BrainInvaders2014b subject 37/38 ...
# Processing BrainInvaders2014b subject 38/38 ...
#
# Processing BrainInvaders2015a subject 1/43 ...
# Processing BrainInvaders2015a subject 2/43 ...
# Processing BrainInvaders2015a subject 3/43 ...
# Processing BrainInvaders2015a subject 4/43 ...
# Processing BrainInvaders2015a subject 5/43 ...
# Processing BrainInvaders2015a subject 6/43 ...
# Processing BrainInvaders2015a subject 7/43 ...
# Processing BrainInvaders2015a subject 8/43 ...
# Processing BrainInvaders2015a subject 9/43 ...
# Processing BrainInvaders2015a subject 10/43 ...
# Processing BrainInvaders2015a subject 11/43 ...
# Processing BrainInvaders2015a subject 12/43 ...
# Processing BrainInvaders2015a subject 13/43 ...
# Processing BrainInvaders2015a subject 14/43 ...
# Processing BrainInvaders2015a subject 15/43 ...
# Processing BrainInvaders2015a subject 16/43 ...
# Processing BrainInvaders2015a subject 17/43 ...
# Processing BrainInvaders2015a subject 18/43 ...
# Processing BrainInvaders2015a subject 19/43 ...
# Processing BrainInvaders2015a subject 20/43 ...
# Processing BrainInvaders2015a subject 21/43 ...
# Processing BrainInvaders2015a subject 22/43 ...
# Processing BrainInvaders2015a subject 23/43 ...
# Processing BrainInvaders2015a subject 24/43 ...
# Processing BrainInvaders2015a subject 25/43 ...
# Processing BrainInvaders2015a subject 26/43 ...
# Processing BrainInvaders2015a subject 27/43 ...
# Processing BrainInvaders2015a subject 28/43 ...
# Processing BrainInvaders2015a subject 29/43 ...
# Processing BrainInvaders2015a subject 30/43 ...
# Processing BrainInvaders2015a subject 31/43 ...
# Processing BrainInvaders2015a subject 32/43 ...
# Processing BrainInvaders2015a subject 33/43 ...
# Processing BrainInvaders2015a subject 34/43 ...
# Processing BrainInvaders2015a subject 35/43 ...
# Processing BrainInvaders2015a subject 36/43 ...
# Processing BrainInvaders2015a subject 37/43 ...
# Processing BrainInvaders2015a subject 38/43 ...
# Processing BrainInvaders2015a subject 39/43 ...
# Processing BrainInvaders2015a subject 40/43 ...
# Processing BrainInvaders2015a subject 41/43 ...
# Processing BrainInvaders2015a subject 42/43 ...
# Processing BrainInvaders2015a subject 43/43 ...
#
# Processing BrainInvaders2015b subject 1/44 ...
# Processing BrainInvaders2015b subject 2/44 ...
# Processing BrainInvaders2015b subject 3/44 ...
# Processing BrainInvaders2015b subject 4/44 ...
# Processing BrainInvaders2015b subject 5/44 ...
# Processing BrainInvaders2015b subject 6/44 ...
# Processing BrainInvaders2015b subject 7/44 ...
# Processing BrainInvaders2015b subject 8/44 ...
# Processing BrainInvaders2015b subject 9/44 ...
# Processing BrainInvaders2015b subject 10/44 ...
# Processing BrainInvaders2015b subject 11/44 ...
# Processing BrainInvaders2015b subject 12/44 ...
# Processing BrainInvaders2015b subject 13/44 ...
# Processing BrainInvaders2015b subject 14/44 ...
# Processing BrainInvaders2015b subject 15/44 ...
# Processing BrainInvaders2015b subject 16/44 ...
# Processing BrainInvaders2015b subject 17/44 ...
# Processing BrainInvaders2015b subject 18/44 ...
# Processing BrainInvaders2015b subject 19/44 ...
# Processing BrainInvaders2015b subject 20/44 ...
# Processing BrainInvaders2015b subject 21/44 ...
# Processing BrainInvaders2015b subject 22/44 ...
# Processing BrainInvaders2015b subject 23/44 ...
# Processing BrainInvaders2015b subject 24/44 ...
# Processing BrainInvaders2015b subject 25/44 ...
# Processing BrainInvaders2015b subject 26/44 ...
# Processing BrainInvaders2015b subject 27/44 ...
# Processing BrainInvaders2015b subject 28/44 ...
# Processing BrainInvaders2015b subject 29/44 ...
# Processing BrainInvaders2015b subject 30/44 ...
# Processing BrainInvaders2015b subject 31/44 ...
# Processing BrainInvaders2015b subject 32/44 ...
# Processing BrainInvaders2015b subject 33/44 ...
# Processing BrainInvaders2015b subject 34/44 ...
# Processing BrainInvaders2015b subject 35/44 ...
# Processing BrainInvaders2015b subject 36/44 ...
# Processing BrainInvaders2015b subject 37/44 ...
# Processing BrainInvaders2015b subject 38/44 ...
# Processing BrainInvaders2015b subject 39/44 ...
# Processing BrainInvaders2015b subject 40/44 ...
# Processing BrainInvaders2015b subject 41/44 ...
# Processing BrainInvaders2015b subject 42/44 ...
# Processing BrainInvaders2015b subject 43/44 ...
# Processing BrainInvaders2015b subject 44/44 ...
#
# Processing BNCI2014-008 subject 1/8 ...
# Processing BNCI2014-008 subject 2/8 ...
# Processing BNCI2014-008 subject 3/8 ...
# Processing BNCI2014-008 subject 4/8 ...
# Processing BNCI2014-008 subject 5/8 ...
# Processing BNCI2014-008 subject 6/8 ...
# Processing BNCI2014-008 subject 7/8 ...
# Processing BNCI2014-008 subject 8/8 ...
#
# Processing BNCI2014-009 subject 1/10 ...
# Processing BNCI2014-009 subject 2/10 ...
# Processing BNCI2014-009 subject 3/10 ...
# Processing BNCI2014-009 subject 4/10 ...
# Processing BNCI2014-009 subject 5/10 ...
# Processing BNCI2014-009 subject 6/10 ...
# Processing BNCI2014-009 subject 7/10 ...
# Processing BNCI2014-009 subject 8/10 ...
# Processing BNCI2014-009 subject 9/10 ...
# Processing BNCI2014-009 subject 10/10 ...
#
# Processing BNCI2015-003 subject 1/10 ...
# Processing BNCI2015-003 subject 2/10 ...
# Processing BNCI2015-003 subject 3/10 ...
# Processing BNCI2015-003 subject 4/10 ...
# Processing BNCI2015-003 subject 5/10 ...
# Processing BNCI2015-003 subject 6/10 ...
# Processing BNCI2015-003 subject 7/10 ...
# Processing BNCI2015-003 subject 8/10 ...
# Processing BNCI2015-003 subject 9/10 ...
# Processing BNCI2015-003 subject 10/10 ...
#
# Processing Cattan2019-VR subject 1/21 ...
# Processing Cattan2019-VR subject 2/21 ...
# Processing Cattan2019-VR subject 3/21 ...
# Processing Cattan2019-VR subject 4/21 ...
# Processing Cattan2019-VR subject 5/21 ...
# Processing Cattan2019-VR subject 6/21 ...
# Processing Cattan2019-VR subject 7/21 ...
# Processing Cattan2019-VR subject 8/21 ...
# Processing Cattan2019-VR subject 9/21 ...
# Processing Cattan2019-VR subject 10/21 ...
# Processing Cattan2019-VR subject 11/21 ...
# Processing Cattan2019-VR subject 12/21 ...
# Processing Cattan2019-VR subject 13/21 ...
# Processing Cattan2019-VR subject 14/21 ...
# Processing Cattan2019-VR subject 15/21 ...
# Processing Cattan2019-VR subject 16/21 ...
# Processing Cattan2019-VR subject 17/21 ...
# Processing Cattan2019-VR subject 18/21 ...
# Processing Cattan2019-VR subject 19/21 ...
# Processing Cattan2019-VR subject 20/21 ...
# Processing Cattan2019-VR subject 21/21 ...
#
# Processing ErpCore2021-ERN subject 1/40 ...
# Processing ErpCore2021-ERN subject 2/40 ...
# Processing ErpCore2021-ERN subject 3/40 ...
# Processing ErpCore2021-ERN subject 4/40 ...
# Processing ErpCore2021-ERN subject 5/40 ...
# Processing ErpCore2021-ERN subject 6/40 ...
# Processing ErpCore2021-ERN subject 7/40 ...
# Processing ErpCore2021-ERN subject 8/40 ...
# Processing ErpCore2021-ERN subject 9/40 ...
# Processing ErpCore2021-ERN subject 10/40 ...
# Processing ErpCore2021-ERN subject 11/40 ...
# Processing ErpCore2021-ERN subject 12/40 ...
# Processing ErpCore2021-ERN subject 13/40 ...
# Processing ErpCore2021-ERN subject 14/40 ...
# Processing ErpCore2021-ERN subject 15/40 ...
# Processing ErpCore2021-ERN subject 16/40 ...
# Processing ErpCore2021-ERN subject 17/40 ...
# Processing ErpCore2021-ERN subject 18/40 ...
# Processing ErpCore2021-ERN subject 19/40 ...
# Processing ErpCore2021-ERN subject 20/40 ...
# Processing ErpCore2021-ERN subject 21/40 ...
# Processing ErpCore2021-ERN subject 22/40 ...
# Processing ErpCore2021-ERN subject 23/40 ...
# Processing ErpCore2021-ERN subject 24/40 ...
# Processing ErpCore2021-ERN subject 25/40 ...
# Processing ErpCore2021-ERN subject 26/40 ...
# Processing ErpCore2021-ERN subject 27/40 ...
# Processing ErpCore2021-ERN subject 28/40 ...
# Processing ErpCore2021-ERN subject 29/40 ...
# Processing ErpCore2021-ERN subject 30/40 ...
# Processing ErpCore2021-ERN subject 31/40 ...
# Processing ErpCore2021-ERN subject 32/40 ...
# Processing ErpCore2021-ERN subject 33/40 ...
# Processing ErpCore2021-ERN subject 34/40 ...
# Processing ErpCore2021-ERN subject 35/40 ...
# Processing ErpCore2021-ERN subject 36/40 ...
# Processing ErpCore2021-ERN subject 37/40 ...
# Processing ErpCore2021-ERN subject 38/40 ...
# Processing ErpCore2021-ERN subject 39/40 ...
# Processing ErpCore2021-ERN subject 40/40 ...
#
# Processing ErpCore2021-LRP subject 1/40 ...
# Processing ErpCore2021-LRP subject 2/40 ...
# Processing ErpCore2021-LRP subject 3/40 ...
# Processing ErpCore2021-LRP subject 4/40 ...
# Processing ErpCore2021-LRP subject 5/40 ...
# Processing ErpCore2021-LRP subject 6/40 ...
# Processing ErpCore2021-LRP subject 7/40 ...
# Processing ErpCore2021-LRP subject 8/40 ...
# Processing ErpCore2021-LRP subject 9/40 ...
# Processing ErpCore2021-LRP subject 10/40 ...
# Processing ErpCore2021-LRP subject 11/40 ...
# Processing ErpCore2021-LRP subject 12/40 ...
# Processing ErpCore2021-LRP subject 13/40 ...
# Processing ErpCore2021-LRP subject 14/40 ...
# Processing ErpCore2021-LRP subject 15/40 ...
# Processing ErpCore2021-LRP subject 16/40 ...
# Processing ErpCore2021-LRP subject 17/40 ...
# Processing ErpCore2021-LRP subject 18/40 ...
# Processing ErpCore2021-LRP subject 19/40 ...
# Processing ErpCore2021-LRP subject 20/40 ...
# Processing ErpCore2021-LRP subject 21/40 ...
# Processing ErpCore2021-LRP subject 22/40 ...
# Processing ErpCore2021-LRP subject 23/40 ...
# Processing ErpCore2021-LRP subject 24/40 ...
# Processing ErpCore2021-LRP subject 25/40 ...
# Processing ErpCore2021-LRP subject 26/40 ...
# Processing ErpCore2021-LRP subject 27/40 ...
# Processing ErpCore2021-LRP subject 28/40 ...
# Processing ErpCore2021-LRP subject 29/40 ...
# Processing ErpCore2021-LRP subject 30/40 ...
# Processing ErpCore2021-LRP subject 31/40 ...
# Processing ErpCore2021-LRP subject 32/40 ...
# Processing ErpCore2021-LRP subject 33/40 ...
# Processing ErpCore2021-LRP subject 34/40 ...
# Processing ErpCore2021-LRP subject 35/40 ...
# Processing ErpCore2021-LRP subject 36/40 ...
# Processing ErpCore2021-LRP subject 37/40 ...
# Processing ErpCore2021-LRP subject 38/40 ...
# Processing ErpCore2021-LRP subject 39/40 ...
# Processing ErpCore2021-LRP subject 40/40 ...
#
# Processing ErpCore2021-MMN subject 1/40 ...
# Processing ErpCore2021-MMN subject 2/40 ...
# Processing ErpCore2021-MMN subject 3/40 ...
# Processing ErpCore2021-MMN subject 4/40 ...
# Processing ErpCore2021-MMN subject 5/40 ...
# Processing ErpCore2021-MMN subject 6/40 ...
# Processing ErpCore2021-MMN subject 7/40 ...
# Processing ErpCore2021-MMN subject 8/40 ...
# Processing ErpCore2021-MMN subject 9/40 ...
# Processing ErpCore2021-MMN subject 10/40 ...
# Processing ErpCore2021-MMN subject 11/40 ...
# Processing ErpCore2021-MMN subject 12/40 ...
# Processing ErpCore2021-MMN subject 13/40 ...
# Processing ErpCore2021-MMN subject 14/40 ...
# Processing ErpCore2021-MMN subject 15/40 ...
# Processing ErpCore2021-MMN subject 16/40 ...
# Processing ErpCore2021-MMN subject 17/40 ...
# Processing ErpCore2021-MMN subject 18/40 ...
# Processing ErpCore2021-MMN subject 19/40 ...
# Processing ErpCore2021-MMN subject 20/40 ...
# Processing ErpCore2021-MMN subject 21/40 ...
# Processing ErpCore2021-MMN subject 22/40 ...
# Processing ErpCore2021-MMN subject 23/40 ...
# Processing ErpCore2021-MMN subject 24/40 ...
# Processing ErpCore2021-MMN subject 25/40 ...
# Processing ErpCore2021-MMN subject 26/40 ...
# Processing ErpCore2021-MMN subject 27/40 ...
# Processing ErpCore2021-MMN subject 28/40 ...
# Processing ErpCore2021-MMN subject 29/40 ...
# Processing ErpCore2021-MMN subject 30/40 ...
# Processing ErpCore2021-MMN subject 31/40 ...
# Processing ErpCore2021-MMN subject 32/40 ...
# Processing ErpCore2021-MMN subject 33/40 ...
# Processing ErpCore2021-MMN subject 34/40 ...
# Processing ErpCore2021-MMN subject 35/40 ...
# Processing ErpCore2021-MMN subject 36/40 ...
# Processing ErpCore2021-MMN subject 37/40 ...
# Processing ErpCore2021-MMN subject 38/40 ...
# Processing ErpCore2021-MMN subject 39/40 ...
# Processing ErpCore2021-MMN subject 40/40 ...
#
# Processing ErpCore2021-N170 subject 1/40 ...
# Processing ErpCore2021-N170 subject 2/40 ...
# Processing ErpCore2021-N170 subject 3/40 ...
# Processing ErpCore2021-N170 subject 4/40 ...
# Processing ErpCore2021-N170 subject 5/40 ...
# Processing ErpCore2021-N170 subject 6/40 ...
# Processing ErpCore2021-N170 subject 7/40 ...
# Processing ErpCore2021-N170 subject 8/40 ...
# Processing ErpCore2021-N170 subject 9/40 ...
# Processing ErpCore2021-N170 subject 10/40 ...
# Processing ErpCore2021-N170 subject 11/40 ...
# Processing ErpCore2021-N170 subject 12/40 ...
# Processing ErpCore2021-N170 subject 13/40 ...
# Processing ErpCore2021-N170 subject 14/40 ...
# Processing ErpCore2021-N170 subject 15/40 ...
# Processing ErpCore2021-N170 subject 16/40 ...
# Processing ErpCore2021-N170 subject 17/40 ...
# Processing ErpCore2021-N170 subject 18/40 ...
# Processing ErpCore2021-N170 subject 19/40 ...
# Processing ErpCore2021-N170 subject 20/40 ...
# Processing ErpCore2021-N170 subject 21/40 ...
# Processing ErpCore2021-N170 subject 22/40 ...
# Processing ErpCore2021-N170 subject 23/40 ...
# Processing ErpCore2021-N170 subject 24/40 ...
# Processing ErpCore2021-N170 subject 25/40 ...
# Processing ErpCore2021-N170 subject 26/40 ...
# Processing ErpCore2021-N170 subject 27/40 ...
# Processing ErpCore2021-N170 subject 28/40 ...
# Processing ErpCore2021-N170 subject 29/40 ...
# Processing ErpCore2021-N170 subject 30/40 ...
# Processing ErpCore2021-N170 subject 31/40 ...
# Processing ErpCore2021-N170 subject 32/40 ...
# Processing ErpCore2021-N170 subject 33/40 ...
# Processing ErpCore2021-N170 subject 34/40 ...
# Processing ErpCore2021-N170 subject 35/40 ...
# Processing ErpCore2021-N170 subject 36/40 ...
# Processing ErpCore2021-N170 subject 37/40 ...
# Processing ErpCore2021-N170 subject 38/40 ...
# Processing ErpCore2021-N170 subject 39/40 ...
# Processing ErpCore2021-N170 subject 40/40 ...
#
# Processing ErpCore2021-N400 subject 1/40 ...
# Processing ErpCore2021-N400 subject 2/40 ...
# Processing ErpCore2021-N400 subject 3/40 ...
# Processing ErpCore2021-N400 subject 4/40 ...
# Processing ErpCore2021-N400 subject 5/40 ...
# Processing ErpCore2021-N400 subject 6/40 ...
# Processing ErpCore2021-N400 subject 7/40 ...
# Processing ErpCore2021-N400 subject 8/40 ...
# Processing ErpCore2021-N400 subject 9/40 ...
# Processing ErpCore2021-N400 subject 10/40 ...
# Processing ErpCore2021-N400 subject 11/40 ...
# Processing ErpCore2021-N400 subject 12/40 ...
# Processing ErpCore2021-N400 subject 13/40 ...
# Processing ErpCore2021-N400 subject 14/40 ...
# Processing ErpCore2021-N400 subject 15/40 ...
# Processing ErpCore2021-N400 subject 16/40 ...
# Processing ErpCore2021-N400 subject 17/40 ...
# Processing ErpCore2021-N400 subject 18/40 ...
# Processing ErpCore2021-N400 subject 19/40 ...
# Processing ErpCore2021-N400 subject 20/40 ...
# Processing ErpCore2021-N400 subject 21/40 ...
# Processing ErpCore2021-N400 subject 22/40 ...
# Processing ErpCore2021-N400 subject 23/40 ...
# Processing ErpCore2021-N400 subject 24/40 ...
# Processing ErpCore2021-N400 subject 25/40 ...
# Processing ErpCore2021-N400 subject 26/40 ...
# Processing ErpCore2021-N400 subject 27/40 ...
# Processing ErpCore2021-N400 subject 28/40 ...
# Processing ErpCore2021-N400 subject 29/40 ...
# Processing ErpCore2021-N400 subject 30/40 ...
# Processing ErpCore2021-N400 subject 31/40 ...
# Processing ErpCore2021-N400 subject 32/40 ...
# Processing ErpCore2021-N400 subject 33/40 ...
# Processing ErpCore2021-N400 subject 34/40 ...
# Processing ErpCore2021-N400 subject 35/40 ...
# Processing ErpCore2021-N400 subject 36/40 ...
# Processing ErpCore2021-N400 subject 37/40 ...
# Processing ErpCore2021-N400 subject 38/40 ...
# Processing ErpCore2021-N400 subject 39/40 ...
# Processing ErpCore2021-N400 subject 40/40 ...
#
# Processing ErpCore2021-P3 subject 1/40 ...
# Processing ErpCore2021-P3 subject 2/40 ...
# Processing ErpCore2021-P3 subject 3/40 ...
# Processing ErpCore2021-P3 subject 4/40 ...
# Processing ErpCore2021-P3 subject 5/40 ...
# Processing ErpCore2021-P3 subject 6/40 ...
# Processing ErpCore2021-P3 subject 7/40 ...
# Processing ErpCore2021-P3 subject 8/40 ...
# Processing ErpCore2021-P3 subject 9/40 ...
# Processing ErpCore2021-P3 subject 10/40 ...
# Processing ErpCore2021-P3 subject 11/40 ...
# Processing ErpCore2021-P3 subject 12/40 ...
# Processing ErpCore2021-P3 subject 13/40 ...
# Processing ErpCore2021-P3 subject 14/40 ...
# Processing ErpCore2021-P3 subject 15/40 ...
# Processing ErpCore2021-P3 subject 16/40 ...
# Processing ErpCore2021-P3 subject 17/40 ...
# Processing ErpCore2021-P3 subject 18/40 ...
# Processing ErpCore2021-P3 subject 19/40 ...
# Processing ErpCore2021-P3 subject 20/40 ...
# Processing ErpCore2021-P3 subject 21/40 ...
# Processing ErpCore2021-P3 subject 22/40 ...
# Processing ErpCore2021-P3 subject 23/40 ...
# Processing ErpCore2021-P3 subject 24/40 ...
# Processing ErpCore2021-P3 subject 25/40 ...
# Processing ErpCore2021-P3 subject 26/40 ...
# Processing ErpCore2021-P3 subject 27/40 ...
# Processing ErpCore2021-P3 subject 28/40 ...
# Processing ErpCore2021-P3 subject 29/40 ...
# Processing ErpCore2021-P3 subject 30/40 ...
# Processing ErpCore2021-P3 subject 31/40 ...
# Processing ErpCore2021-P3 subject 32/40 ...
# Processing ErpCore2021-P3 subject 33/40 ...
# Processing ErpCore2021-P3 subject 34/40 ...
# Processing ErpCore2021-P3 subject 35/40 ...
# Processing ErpCore2021-P3 subject 36/40 ...
# Processing ErpCore2021-P3 subject 37/40 ...
# Processing ErpCore2021-P3 subject 38/40 ...
# Processing ErpCore2021-P3 subject 39/40 ...
# Processing ErpCore2021-P3 subject 40/40 ...
#
# Processing Lee2019-ERP subject 1/54 ...
# Processing Lee2019-ERP subject 2/54 ...
# Processing Lee2019-ERP subject 3/54 ...
# Processing Lee2019-ERP subject 4/54 ...
# Processing Lee2019-ERP subject 5/54 ...
# Processing Lee2019-ERP subject 6/54 ...
# Processing Lee2019-ERP subject 7/54 ...
# Processing Lee2019-ERP subject 8/54 ...
# Processing Lee2019-ERP subject 9/54 ...
# Processing Lee2019-ERP subject 10/54 ...
# Processing Lee2019-ERP subject 11/54 ...
# Processing Lee2019-ERP subject 12/54 ...
# Processing Lee2019-ERP subject 13/54 ...
# Processing Lee2019-ERP subject 14/54 ...
# Processing Lee2019-ERP subject 15/54 ...
# Processing Lee2019-ERP subject 16/54 ...
# Processing Lee2019-ERP subject 17/54 ...
# Processing Lee2019-ERP subject 18/54 ...
# Processing Lee2019-ERP subject 19/54 ...
# Processing Lee2019-ERP subject 20/54 ...
# Processing Lee2019-ERP subject 21/54 ...
# Processing Lee2019-ERP subject 22/54 ...
# Processing Lee2019-ERP subject 23/54 ...
# Processing Lee2019-ERP subject 24/54 ...
# Processing Lee2019-ERP subject 25/54 ...
# Processing Lee2019-ERP subject 26/54 ...
# Processing Lee2019-ERP subject 27/54 ...
# Processing Lee2019-ERP subject 28/54 ...
# Processing Lee2019-ERP subject 29/54 ...
# Processing Lee2019-ERP subject 30/54 ...
# Processing Lee2019-ERP subject 31/54 ...
# Processing Lee2019-ERP subject 32/54 ...
# Processing Lee2019-ERP subject 33/54 ...
# Processing Lee2019-ERP subject 34/54 ...
# Processing Lee2019-ERP subject 35/54 ...
# Processing Lee2019-ERP subject 36/54 ...
# Processing Lee2019-ERP subject 37/54 ...
# Processing Lee2019-ERP subject 38/54 ...
# Processing Lee2019-ERP subject 39/54 ...
# Processing Lee2019-ERP subject 40/54 ...
# Processing Lee2019-ERP subject 41/54 ...
# Processing Lee2019-ERP subject 42/54 ...
# Processing Lee2019-ERP subject 43/54 ...
# Processing Lee2019-ERP subject 44/54 ...
# Processing Lee2019-ERP subject 45/54 ...
# Processing Lee2019-ERP subject 46/54 ...
# Processing Lee2019-ERP subject 47/54 ...
# Processing Lee2019-ERP subject 48/54 ...
# Processing Lee2019-ERP subject 49/54 ...
# Processing Lee2019-ERP subject 50/54 ...
# Processing Lee2019-ERP subject 51/54 ...
# Processing Lee2019-ERP subject 52/54 ...
# Processing Lee2019-ERP subject 53/54 ...
# Processing Lee2019-ERP subject 54/54 ...
