# %%
from moabb.paradigms import P300
from moabb.datasets import *

paradigm = P300(resample=48)
datasets = paradigm.datasets

"""
datasets=[
    BNCI2014_008(),
    BNCI2014_009(),
    BNCI2015_003(),
    BI2012(),
    BI2013a(),
    BI2014a(),
    BI2014b(),
    BI2015a(),
    BI2015b(),
    Cattan2019_VR(),
    EPFLP300(),
    Huebner2017(),
    Huebner2018(),
    Lee2019_ERP(),
]"""
datasets = [BNCI2014_008()]
for dataset in datasets:
    print(dataset.code)
# Out:
# BNCI2014-008

# %%
from tqdm import tqdm

cache_config = dict(
    use=True,
    save_raw=False,
    save_epochs=False,
    save_array=True,
    overwrite_raw=False,
    overwrite_epochs=False,
    overwrite_array=False,
)
for dataset in datasets:
    n_subjects = len(dataset.subject_list)
    for si, subject in tqdm(list(enumerate(dataset.subject_list)), desc=f'Processing {dataset.code}'):
        try:
            paradigm.get_data(dataset, subjects=[subject], cache_config=cache_config)
        except Exception as e:
            print(e)
    print()
# Out:
# Processing BNCI2014-008: 100%|██████████| 8/8 [00:01<00:00,  5.07it/s]
