# %%
import hoda
import tensorly as tl
import mne
# %load_ext autoreload
# %autoreload 2

# !pip install line_profiler
# %load_ext line_profiler

tl.tenalg.set_backend('einsum')
tl.plugins.use_opt_einsum()
    
mne.set_log_level('ERROR')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: line_profiler in /home/arne/.local/lib/python3.12/site-packages (4.1.2)
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: /usr/bin/python3 -m pip install --upgrade pip
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
from moabb.paradigms import P300, MotorImagery
from moabb.datasets import *
from mne.decoding import Scaler

paradigm = P300(resample=46, tmin=0)
dataset = BNCI2015_003()


epochs, labels, meta = paradigm.get_data(dataset=dataset, 
                                         subjects=[2],
                                         return_epochs=True)
session = meta['session'].unique()[0]
idc = meta['session'] == session
epochs = epochs[idc]
labels = labels[idc]
meta = meta[idc]

#epochs.pick_channels(['Cz'])

epochs._data = Scaler(scalings='mean', with_mean=True).fit_transform(epochs._data)
# Out:
# /home/arne/.virtualenvs/hoda/src/moabb/moabb/datasets/preprocessing.py:279: UserWarning: warnEpochs <Epochs |  2700 events (all good), 0 – 0.800781 s, baseline off, ~34.0 MB, data loaded,
#  'Target': 75
#  'NonTarget': 2625>
#   warn(f"warnEpochs {epochs}")
# /home/arne/.virtualenvs/hoda/src/moabb/moabb/datasets/preprocessing.py:279: UserWarning: warnEpochs <Epochs |  2700 events (all good), 0 – 0.800781 s, baseline off, ~34.0 MB, data loaded,
#  'Target': 75
#  'NonTarget': 2625>
#   warn(f"warnEpochs {epochs}")

# %%
epochs
# Out:
# <EpochsArray |  5400 events (all good), 0 – 0.782609 s, baseline off, ~12.2 MB, data loaded, with metadata,
#  'Target': 150
#  'NonTarget': 5250>

# %%
import tensorly.decomposition
import matplotlib.pyplot as plt
import tensorly as tl
import numpy as np

X = tl.tensor(epochs.get_data())
y = labels

X.shape
# Out:
# (5400, 8, 37)

# %%
from hoda.hoda import HODA, f_multiway,trunc_eigh
from hoda.backend import lobpcg
import warnings

from hoda.hoda import mode_scatter
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectFwe
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import pandas as pd

hoda = HODA(
        rank=2,
        max_iter=256,
        tol=1e-12,
        init ='eye',
        shrinkage='lw',
        toeplitz=None,
        obj='rt',
        solver='lanczos',
        taper=False,
        extra_train_info=False,
        verbose=True,
        random_state=42,
        delta=None,

)
display(hoda)
# Out:
# HODA(init='eye', random_state=42, rank=2, tol=1e-12, verbose=True)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('default')

# %lprun -f hoda.fit_backward hoda.fit_backward(X,y)
# Out:
#   0%|          | 0/256 [00:00<?, ?it/s]
# Timer unit: 1e-09 s
#
# Total time: 2.91881 s
# File: /home/arne/Workspace/PhD/hoda-bci/src/hoda/hoda.py
# Function: fit_backward at line 167
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    167                                               def fit_backward(
#    168                                                   self, X, y, X_centered=None, means=None, classes=None, class_counts=None
#    169                                               ):
#    170         1       8893.0   8893.0      0.0          assert tl.is_tensor(X)
#    171                                                   # TODO: calculate train info for initialization
#    172                                                   # Convert to tensor
#    173                                                   # if not tl.is_tensor(X):
#    174                                                   #    X = tl.tensor(X)
#    175         1       2983.0   2983.0      0.0          n_samples, *shape = X.shape
#    176         1        552.0    552.0      0.0          order = len(shape)
#    177
#    178                                                   # Determine classses  and center
#    179         1        248.0    248.0      0.0          if classes is None or class_counts is None:
#    180         1     724561.0 724561.0      0.0              self.classes_, class_counts = np.unique(y, return_counts=True)
#    181         1       7329.0   7329.0      0.0              class_counts = tl.tensor(class_counts)
#    182                                                   else:
#    183                                                       self.classes_ = classes
#    184         1        271.0    271.0      0.0          if X_centered is None or means is None:
#    185         1   10675808.0    1e+07      0.4              self.means_, X_centered = center(X, y, self.classes_)
#    186                                                   else:
#    187                                                       self.means_ = means
#    188
#    189                                                   # Initialize train info
#    190         1       2032.0   2032.0      0.0          self.train_info_ = dict(backward=[])
#    191
#    192                                                   # Initialize backward projections and covariances
#    193         1      45612.0  45612.0      0.0          self._init(X)
#    194         1        933.0    933.0      0.0          self.scatter_w_ = [None] * order
#    195
#    196                                                   # Determine solver parameters
#    197         1       1983.0   1983.0      0.0          if self.obj not in OBJECTIVES.keys():
#    198                                                       raise ValueError(f"objective must be one of {list(OBJECTIVES.keys())}")
#    199         1        588.0    588.0      0.0          solver_params = self.solver_params
#    200         1        349.0    349.0      0.0          if solver_params is None:
#    201         1        502.0    502.0      0.0              solver_params = dict()
#    202
#    203                                                   # Calculate means and center
#    204         1      38378.0  38378.0      0.0          means_centered = self.means_ - tl.mean(self.means_, axis=0)
#    205
#    206                                                   # Calculate total scatter
#    207         1        573.0    573.0      0.0          scatter_t = [None] * order
#    208         3       2934.0    978.0      0.0          for k in range(order):
#    209         4   69040535.0    2e+07      2.4              scatter_w, _ = mode_scatter(
#    210         2       1122.0    561.0      0.0                  X_centered,
#    211         2        899.0    449.5      0.0                  k,
#    212         2        919.0    459.5      0.0                  assume_centered=True,
#    213         2       1559.0    779.5      0.0                  shrinkage=self.shrinkage,
#    214         2       2070.0   1035.0      0.0                  toeplitz=self.toeplitz,
#    215         2       1549.0    774.5      0.0                  taper=self.taper,
#    216                                                       )
#    217         4     675226.0 168806.5      0.0              scatter_b, _ = mode_scatter(
#    218         2      31344.0  15672.0      0.0                  self.means_, k, weights=tl.sqrt(class_counts), shrinkage=0
#    219                                                       )
#    220         2      10030.0   5015.0      0.0              scatter_t[k] = scatter_w + scatter_b
#    221
#    222                                                   # Iteratively find projections
#    223         1       3571.0   3571.0      0.0          iterator = range(1, self.max_iter + 1)
#    224         1       1081.0   1081.0      0.0          if self.verbose:
#    225         1   50592488.0    5e+07      1.7              iterator = tqdm(iterator)
#    226         1    5129061.0    5e+06      0.2              iterator.set_description(f"Backward model rank={self.rank_}")
#    227        38   63414555.0    2e+06      2.2          for self.iter_ in iterator:
#    228        38      53508.0   1408.1      0.0              converged = True
#    229       114     210549.0   1846.9      0.0              for k in range(order):
#    230        76     156415.0   2058.1      0.0                  modes = range(1, order + 1)
#    231       152  704858906.0    5e+06     24.1                  X_centered_proj = tl.tenalg.multi_mode_dot(
#    232        76      53957.0    710.0      0.0                      X_centered,
#    233        76      68555.0    902.0      0.0                      self.weights_,
#    234        76      53343.0    701.9      0.0                      modes=modes,
#    235        76      51507.0    677.7      0.0                      skip=k,
#    236        76      49942.0    657.1      0.0                      transpose=True,
#    237                                                           )
#    238
#    239        76     359635.0   4732.0      0.0                  if isinstance(self.shrinkage, tuple):
#    240                                                               shrinkage = self.shrinkage[k]
#    241                                                           else:
#    242        76     117953.0   1552.0      0.0                      shrinkage = self.shrinkage
#    243
#    244       152 1362656198.0    9e+06     46.7                  scatter_w, shrinkage = mode_scatter(
#    245        76      60995.0    802.6      0.0                      X_centered_proj,
#    246        76      61661.0    811.3      0.0                      k,
#    247        76      69998.0    921.0      0.0                      assume_centered=True,
#    248        76      60088.0    790.6      0.0                      shrinkage=shrinkage,
#    249        76      95977.0   1262.9      0.0                      toeplitz=self.toeplitz,
#    250        76     145353.0   1912.5      0.0                      taper=self.taper,
#    251                                                           )
#    252
#    253                                                           # Calculate between class scatter
#    254       152   31515301.0 207337.5      1.1                  means_centered_proj = tl.tenalg.multi_mode_dot(
#    255        76     174181.0   2291.9      0.0                      means_centered, self.weights_, modes=modes, skip=k, transpose=True
#    256                                                           )
#    257       152   36297253.0 238797.7      1.2                  scatter_b, _ = mode_scatter(
#    258        76     101649.0   1337.5      0.0                      means_centered_proj,
#    259        76      64451.0    848.0      0.0                      k,
#    260        76    4679988.0  61578.8      0.2                      weights=tl.sqrt(class_counts),
#    261        76      69170.0    910.1      0.0                      shrinkage=0,
#    262        76      88670.0   1166.7      0.0                      assume_centered=True,
#    263                                                           )
#    264
#    265                                                           # Solve
#    266       152     535582.0   3523.6      0.0                  A, B, largest = OBJECTIVES[self.obj](
#    267        76     101553.0   1336.2      0.0                      scatter_b, scatter_w, self.weights_[k]
#    268                                                           )
#    269        76     141833.0   1866.2      0.0                  if self.solver == "lobpcg":
#    270                                                               solver_params["init"] = copy(self.weights_[k])
#    271       152  464752120.0    3e+06     15.9                  u, w = trunc_eigh(
#    272        76      69465.0    914.0      0.0                      A,
#    273        76      62682.0    824.8      0.0                      B=B,
#    274        76     776596.0  10218.4      0.0                      rank=self.rank_[k],
#    275        76      77218.0   1016.0      0.0                      method=self.solver,
#    276        76      64976.0    854.9      0.0                      largest=largest,
#    277        76      74038.0    974.2      0.0                      solver_params=solver_params,
#    278                                                           )
#    279        76     172578.0   2270.8      0.0                  if self.delta is not None:
#    280                                                               idc = np.argsort(w)
#    281                                                               w = w[idc]
#    282                                                               u = u[:, idc]
#    283                                                               u = u[:, tl.cumsum(w) / tl.sum(w) > self.delta]
#    284        76     157375.0   2070.7      0.0                  new_rank = u.shape[-1]
#    285                                                           # Re-orthogonalize
#    286        76     123660.0   1627.1      0.0                  if self.solver == "lobpcg":
#    287                                                               solver_params["init"] = u
#    288       152   78779718.0 518287.6      2.7                  u, w = trunc_eigh(
#    289        76    5095284.0  67043.2      0.2                      u @ u.T @ (scatter_t[k]) @ u @ u.T,
#    290                                                               # rank=self.rank_[k],
#    291        76      76610.0   1008.0      0.0                      rank=new_rank,
#    292        76      94558.0   1244.2      0.0                      method=self.solver,
#    293        76      89551.0   1178.3      0.0                      largest=largest,
#    294        76      72635.0    955.7      0.0                      solver_params=solver_params,
#    295                                                           )
#    296                                                           # Flip sign
#    297        76    1152885.0  15169.5      0.0                  sign = tl.sign(u[0, :])
#    298        76    1153424.0  15176.6      0.0                  u *= sign
#    299                                                           # Normalize
#    300        76    7004822.0  92168.7      0.2                  u = u / tl.norm(u, axis=0)
#    301
#    302                                                           # Calculate update and check convergence
#    303        76     251904.0   3314.5      0.0                  if u.shape[-1] != self.weights_[k].shape[-1]:
#    304                                                               update = np.inf
#    305                                                           else:
#    306        76    3835710.0  50469.9      0.1                      update = tl.norm(u - self.weights_[k])
#    307        76    3191212.0  41989.6      0.1                      update /= tl.norm(self.weights_[k])
#    308
#    309        76     462358.0   6083.7      0.0                  converged = update < self.tol and converged
#    310
#    311                                                           # Update weights
#    312        76     148651.0   1955.9      0.0                  self.weights_[k] = u
#    313
#    314                                                           # Store mode training information
#    315       152     376263.0   2475.4      0.0                  train_info_row = dict(
#    316        76     117170.0   1541.7      0.0                      iteration=self.iter_,
#    317        76      74012.0    973.8      0.0                      mode=k,
#    318        76     161345.0   2123.0      0.0                      update=float(update),
#    319        76     104403.0   1373.7      0.0                      shrinkage=float(shrinkage),
#    320        76      73960.0    973.2      0.0                      rank=new_rank,
#    321        76    2744001.0  36105.3      0.1                      objective=float(tl.sum(w)),
#    322                                                           )
#    323        76     178896.0   2353.9      0.0                  self.scatter_w_[k] = scatter_w
#    324        76     116851.0   1537.5      0.0                  if self.extra_train_info:
#    325                                                               train_info_row.update(
#    326                                                                   self._extra_train_info_backward(
#    327                                                                       X,
#    328                                                                       y,
#    329                                                                       class_counts,
#    330                                                                   )
#    331                                                               )
#    332        76     207121.0   2725.3      0.0                  self.train_info_["backward"].append(train_info_row)
#    333
#    334                                                       # Exit if converged
#    335        38      36881.0    970.6      0.0              if converged:
#    336         1    3278142.0    3e+06      0.1                  break
#    337                                                   # Convert train_info to list dict
#    338         2     227435.0 113717.5      0.0          self.train_info_["backward"] = {
#    339                                                       k: [dic[k] for dic in self.train_info_["backward"]]
#    340         1       2384.0   2384.0      0.0              for k in self.train_info_["backward"][0]
#    341                                                   }

# %%
df = pd.DataFrame(hoda.train_info_['backward'])
display(df)

fig, axs = plt.subplots(4,1, sharex=True)
sns.lineplot(data=df, x='iteration', y='update',hue='mode', ax=axs[0])
axs[0].axhline(hoda.tol, color='grey', linestyle='--')
axs[0].set_yscale('log')
sns.lineplot(data=df, x='iteration', y='shrinkage',hue='mode', ax=axs[1])
sns.lineplot(data=df, x='iteration', y='objective',hue='mode', ax=axs[2])
sns.lineplot(data=df, x='iteration', y='rank',hue='mode', ax=axs[3])
if hoda.extra_train_info:
    fig, axs = plt.subplots(2,1, sharex=True)
    sns.lineplot(data=df, x=df.index, y='F_tr', ax=axs[0])
    sns.lineplot(data=df, x=df.index, y='F_rt', ax=axs[1])
# Out:
#     iteration  mode        update  shrinkage  rank  objective
# 0           1     0  1.487541e+00   0.000676     2   0.020088
# 1           1     1  1.363804e+00   0.010637     2   0.025953
# 2           2     0  1.532855e+00   0.000884     2   0.018359
# 3           2     1  5.020569e-01   0.004815     2   0.006324
# 4           3     0  4.845733e-01   0.000722     2   0.013129
# ..        ...   ...           ...        ...   ...        ...
# 71         36     1  2.993280e-12   0.005368     2   0.026512
# 72         37     0  1.472396e-12   0.000723     2   0.013653
# 73         37     1  1.452180e-12   0.005368     2   0.026512
# 74         38     0  7.217066e-13   0.000723     2   0.013653
# 75         38     1  7.061658e-13   0.005368     2   0.026512
#
# [76 rows x 6 columns]

# %%
# %lprun -f hoda.fit_forward hoda.fit_forward(X,y)
# Out:
#   0%|          | 0/256 [00:00<?, ?it/s]
# Timer unit: 1e-09 s
#
# Total time: 0.885551 s
# File: /home/arne/Workspace/PhD/hoda-bci/src/hoda/hoda.py
# Function: fit_forward at line 343
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    343                                               def fit_forward(self, X, y, X_centered=None, Xt=None, Xt_centered=None):
#    344         1      10593.0  10593.0      0.0          assert tl.is_tensor(X)
#    345         1       3200.0   3200.0      0.0          n_samples, *shape = X.shape
#    346         1        607.0    607.0      0.0          order = len(shape)
#    347
#    348                                                   # Project
#    349
#    350         1        432.0    432.0      0.0          if Xt is None:
#    351         1    7980300.0    8e+06      0.9              Xt = self.transform(X)
#    352         1        813.0    813.0      0.0          if Xt_centered is None:
#    353         1    3740151.0    4e+06      0.4              _, Xt_centered = center(Xt, y)
#    354         1        946.0    946.0      0.0          if X_centered is None:
#    355         1   11983149.0    1e+07      1.4              _, X_centered = center(X, y)
#    356
#    357                                                   # Initialize
#    358         1      30570.0  30570.0      0.0          self.aps_ = [copy(w) for w in self.weights_]
#    359         1       2607.0   2607.0      0.0          self.train_info_["forward"] = []
#    360
#    361                                                   # Calculate forward model
#    362         1       3741.0   3741.0      0.0          iterator = range(0, self.max_iter)
#    363         1       2124.0   2124.0      0.0          if self.verbose:
#    364         1   32882284.0    3e+07      3.7              iterator = tqdm(iterator)
#    365         1     823175.0 823175.0      0.1              iterator.set_description("Forward model ")
#    366         1       2234.0   2234.0      0.0          update = np.inf
#    367         9   11148165.0    1e+06      1.3          for i in iterator:
#    368         9       8072.0    896.9      0.0              converged = True
#    369        27      46170.0   1710.0      0.0              for k in range(order):
#    370                                                           # Initialize or calculate activation pattern
#    371        18      14587.0    810.4      0.0                  if not i:
#    372         2      32098.0  16049.0      0.0                      ap = copy(self.weights_[k])
#    373         2       1937.0    968.5      0.0                      update = np.inf
#    374         2       2277.0   1138.5      0.0                      shrink = np.nan
#    375                                                           else:
#    376        16      37882.0   2367.6      0.0                      modes = range(1, order + 1)
#    377        32   26591710.0 830990.9      3.0                      G = tl.tenalg.multi_mode_dot(
#    378        16      18346.0   1146.6      0.0                          Xt_centered, self.aps_, modes=modes, skip=k
#    379                                                               )
#    380
#    381                                                               # modes = [0] + [kk + 1 for kk in range(order) if kk != k]
#    382                                                               # cov_cross = tl.tensordot(X_centered, G, axes=(modes, modes))
#    383                                                               # cov_g, shrink = mode_scatter(
#    384                                                               #    G,
#    385                                                               #    k,
#    386                                                               #    shrinkage=self.shrinkage,
#    387                                                               #    # shrinkage=0,
#    388                                                               #    assume_centered=True,
#    389                                                               # )
#    390                                                               # ap = tl.solve(cov_g.T, cov_cross.T).T
#    391
#    392        16   10071857.0 629491.1      1.1                      Gk = tl.unfold(G, k + 1)
#    393        16   99994995.0    6e+06     11.3                      Xk = tl.unfold(X_centered, k + 1)
#    394        16  675705685.0    4e+07     76.3                      ap, *_ = lstsq(Gk.T, Xk.T)
#    395                                                               # ap = lstsq_ridge(Gk.T, Xk.T, lambda_=0)
#    396        16      52549.0   3284.3      0.0                      ap = ap.T
#    397        16      14235.0    889.7      0.0                      shrink = 0
#    398
#    399        16    1685877.0 105367.3      0.2                      update = tl.norm(ap - self.aps_[k])
#    400        16     770630.0  48164.4      0.1                      update /= tl.norm(self.aps_[k])
#    401
#    402        18      46297.0   2572.1      0.0                  self.aps_[k] = ap
#    403        18      92901.0   5161.2      0.0                  converged = update < self.tol and converged
#    404
#    405                                                           # Store training info
#    406        18      39665.0   2203.6      0.0                  train_info_row = dict()
#    407        18      22894.0   1271.9      0.0                  train_info_row["iteration"] = i
#    408        18      22614.0   1256.3      0.0                  train_info_row["mode"] = k
#    409        18      42151.0   2341.7      0.0                  train_info_row["update"] = float(update)
#    410        18      35573.0   1976.3      0.0                  train_info_row["shrinkage"] = float(shrink)
#    411        18      24128.0   1340.4      0.0                  if self.extra_train_info:
#    412                                                               train_info_row.update(self._extra_train_info_forward(X, Xt, y))
#    413        18      47940.0   2663.3      0.0                  self.train_info_["forward"].append(train_info_row)
#    414
#    415         9       7156.0    795.1      0.0              if converged:
#    416         1    1434878.0    1e+06      0.2                  break
#    417
#    418         2      69055.0  34527.5      0.0          self.train_info_["forward"] = {
#    419                                                       k: [dic[k] for dic in self.train_info_["forward"]]
#    420         1       1922.0   1922.0      0.0              for k in self.train_info_["forward"][0]
#    421                                                   }

# %%
df = pd.DataFrame(hoda.train_info_['forward'])
display(df)

fig, axs = plt.subplots( 2,1, sharex=True)
sns.lineplot(data=df, x='iteration', y='update',hue='mode', ax=axs[0])
axs[0].axhline(hoda.tol, color='grey', linestyle='--')
axs[0].set_yscale('log')
sns.lineplot(data=df, x='iteration', y='shrinkage',hue='mode', ax=axs[1])
if hoda.extra_train_info:
    fig, axs = plt.subplots(2,1, sharex=True)
    sns.lineplot(data=df, x=df.index, y='mse', ax=axs[0])
    axs[0].set_yscale('log')
    sns.lineplot(data=df, x=df.index, y='err_cross_corr', ax=axs[1])
    axs[1].set_yscale('log')
# Out:
#     iteration  mode        update  shrinkage
# 0           0     0           inf        NaN
# 1           0     1           inf        NaN
# 2           1     0  4.118718e+00        0.0
# 3           1     1  8.879858e-01        0.0
# 4           2     0  1.955928e-02        0.0
# 5           2     1  1.524232e-03        0.0
# 6           3     0  1.360928e-04        0.0
# 7           3     1  2.375467e-05        0.0
# 8           4     0  2.467166e-06        0.0
# 9           4     1  4.597913e-07        0.0
# 10          5     0  4.779850e-08        0.0
# 11          5     1  8.960391e-09        0.0
# 12          6     0  9.309649e-10        0.0
# 13          6     1  1.746982e-10        0.0
# 14          7     0  1.814729e-11        0.0
# 15          7     1  3.406173e-12        0.0
# 16          8     0  3.538915e-13        0.0
# 17          8     1  6.652368e-14        0.0

# %%
import math
from hoda.util import center

X = tl.tensor(X)
G = hoda.transform(X)
X_approx = hoda.inv_transform(G)
err = X-X_approx

# %%
n_samples = X.shape[0]
G_flat = tl.to_numpy(G.reshape((n_samples, -1), order='F'), )
err_flat = tl.to_numpy(err.reshape((n_samples, -1), order='F'))
cross_corr = np.corrcoef(G_flat, err_flat, rowvar=False)
cross_corr = cross_corr[G_flat.shape[-1]:,:G_flat.shape[-1]].T
sns.heatmap(cross_corr,  cmap='RdBu_r', center=0, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
#G_cov = tl.tensordot(G.T, G, axes=1)/(n_samples-1)
G_flat = tl.to_numpy(G.reshape(n_samples, -1))
sns.heatmap(np.corrcoef(G_flat, rowvar=False),  cmap='RdBu_r', center=0)
# Out:
# <Axes: >

# %%
import numpy as np
from mne.viz import plot_topomap
import matplotlib.pyplot as plt
import tensorly as tl

col_wrap = 4


n_col = col_wrap
n_row = int( np.ceil(hoda.rank_[0] / col_wrap)) 
fig, axs = plt.subplots(n_row, n_col, layout='tight')
vmax = float(tl.max(tl.abs(hoda.weights_[0])))
for i in range(hoda.rank_[0]):
    w = tl.to_numpy(hoda.weights_[0][:,i])
    plot_topomap(w, epochs.info, axes=axs.flatten()[i], show=False, vlim=[-vmax, vmax])

order = X.ndim-1
for k in range(1, order):
    n_row = int( np.ceil(hoda.rank_[k] / col_wrap)) 
    fig, axs = plt.subplots(n_row, n_col,  layout='tight', sharex=True, sharey=True)
    for i in range(hoda.rank_[k]):
        w = tl.to_numpy(hoda.weights_[k][:,i])
        axs.flatten()[i].plot(w)
        axs.flatten()[i].set_xlabel(f'Mode {k}')
        axs.flatten()[i].sharey(axs.flatten()[0])
    axs.flatten()[0].set_ylabel('Weight');

# %%
n_row = int(np.ceil(hoda.rank_[0] / col_wrap)) 
fig, axs = plt.subplots(n_row, n_col, layout='tight')
A = hoda.aps_[0]
vmax = float(tl.max(tl.abs(A)))
for i in range(hoda.rank_[0]):
    a = tl.to_numpy(A[:,i])
    plot_topomap(a, epochs.info, axes=axs.flatten()[i], show=False, vlim=[-vmax, vmax])

for k in range(1, order):
    n_row = int(np.ceil(hoda.rank_[k] / col_wrap)) 
    fig, axs = plt.subplots(
        n_row, n_col, 
        layout='tight', 
        sharex=True,
        sharey=True
    )
    A = hoda.aps_[k]
    for i in range(hoda.rank_[k]):
        a = tl.to_numpy(A[:,i])
        axs.flatten()[i].plot(a)
        axs.flatten()[i].set_xlabel(f'Mode {k}')
        axs.flatten()[i].sharey(axs.flatten()[0])
    axs.flatten()[0].set_ylabel('Amplitude');

# %%
Xt = hoda.transform(X)

# %%
from hoda.util import f_multiway, f_oneway

F, p = f_oneway(Xt,y)

classes = np.unique(y)
y_like_Xt = tl.zeros_like(Xt)
for ci, c in enumerate(classes):
    y_like_Xt[y==c] = ci


F_sp, p_sp = f_oneway(tl.unfold(Xt, 0+1).T, tl.unfold(y_like_Xt, 0+1).T[:,0])
F_tmp, p_tmp = f_oneway(tl.unfold(Xt, 1+1).T, tl.unfold(y_like_Xt, 1+1).T[:,0])


F_sp = tl.to_numpy(F_sp)
F_tmp = tl.to_numpy(F_tmp)
F = tl.to_numpy(F)
p= tl.to_numpy(p)
print(p)
g = sns.JointGrid()
sns.heatmap(F, vmin=0, ax=g.ax_joint,
            #mask=p>0.5/p.size,
            cbar=False,
            cmap='Blues')
g.ax_marg_x.bar(np.arange(p.shape[1]) + 0.5, F_tmp)
g.ax_marg_y.barh(np.arange(p.shape[0]) + 0.5, F_sp)
# Out:
# [[1.60838443e-74 2.82009130e-47]
#  [3.78371074e-79 1.19031696e-07]]
# <BarContainer object of 2 artists>

# %%
_,Xt_centered = center(Xt, y)
norm = tl.norm(Xt_centered, axis=0)
sns.heatmap(tl.to_numpy(norm), vmin=0)
# Out:
# <Axes: >

# %%
from sklearn.feature_selection import SelectFwe

Xt_flat = tl.to_numpy(Xt.reshape((Xt.shape[0], -1)))
Xt_flat.shape
# Out:
# (5400, 4)

# %%
from sklearn.decomposition import PCA
import seaborn as sns
from matplotlib import pyplot as plt

if Xt.shape[-1] > 1:
    n_components = 2
    decomp  = PCA(n_components=n_components, whiten=True)
    Xt_viz = decomp.fit_transform(Xt_flat)
    df = pd.DataFrame(Xt_viz, columns=['PC1', 'PC2'])
    df['label'] = y
    df=df.reset_index()
    print(df)
    #sns.scatterplot(data=df, x='PC1', y='PC2', hue='label',)
    sns.kdeplot(data=df, x='PC1', y='PC2', hue='label',)
    ax = plt.gca()    
    ax.spines['bottom'].set_position('zero')
    ax.spines['left'].set_position('zero')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
# Out:
#       index       PC1       PC2      label
# 0         0 -1.625080  0.599205  NonTarget
# 1         1  0.611379 -1.095450  NonTarget
# 2         2 -0.087379  0.921614  NonTarget
# 3         3  0.180198 -1.032325  NonTarget
# 4         4  0.927927 -1.677918  NonTarget
# ...     ...       ...       ...        ...
# 5395   5395  0.294713  0.427389  NonTarget
# 5396   5396 -1.081119 -0.662403  NonTarget
# 5397   5397  0.318052  0.898298  NonTarget
# 5398   5398  0.647683 -0.533284  NonTarget
# 5399   5399 -0.546351 -0.088106  NonTarget
#
# [5400 rows x 4 columns]

# %%
import numpy as np

evokeds = []
vmax=0
for cls in np.unique(labels):
    evoked = epochs[cls].average()
    evokeds.append(evoked)
    vmax= max(vmax, np.max(np.abs(evoked.data))*1.2*1e6)

ts_args=dict(ylim=dict(eeg=[-vmax,vmax]))
joint_args=dict(ts_args=ts_args)

for evoked  in evokeds:
    if len(evoked.ch_names) > 1:
        evoked.apply_baseline((None,0)).plot_joint(title=cls, **joint_args)
    else:
        evoked.plot(**ts_args)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 15
#      13 for evoked  in evokeds:
#      14     if len(evoked.ch_names) > 1:
# ---> 15         evoked.apply_baseline((None,0)).plot_joint(title=cls, **joint_args)
#      16     else:
#      17         evoked.plot(**ts_args)
#
# File <decorator-gen-193>:12, in apply_baseline(self, baseline, verbose)
#
# File ~/.virtualenvs/hoda/lib/python3.9/site-packages/mne/evoked.py:379, in Evoked.apply_baseline(self, baseline, verbose)
#     357 @verbose
#     358 def apply_baseline(self, baseline=(None, 0), *, verbose=None):
#     359     """Baseline correct evoked data.
#     360
#     361     Parameters
#    (...)
#     377     .. versionadded:: 0.13.0
#     378     """
# --> 379     baseline = _check_baseline(baseline, times=self.times, sfreq=self.info["sfreq"])
#     380     if self.baseline is not None and baseline is None:
#     381         raise ValueError(
#     382             "The data has already been baseline-corrected. "
#     383             "Cannot remove existing baseline correction."
#     384         )
#
# File ~/.virtualenvs/hoda/lib/python3.9/site-packages/mne/baseline.py:189, in _check_baseline(baseline, times, sfreq, on_baseline_outside_data)
#     187 # check default value of baseline and `tmin=0`
#     188 if baseline == (None, 0) and tmin == 0:
# --> 189     raise ValueError(
#     190         "Baseline interval is only one sample. Use `baseline=(0, 0)` if this is "
#     191         "desired."
#     192     )
#     194 baseline_tmin, baseline_tmax = baseline
#     196 if baseline_tmin is None:
#
# ValueError: Baseline interval is only one sample. Use `baseline=(0, 0)` if this is desired.

# %%
epochs_rec = epochs.copy()
epochs_rec._data = tl.to_numpy(hoda.inv_transform(hoda.transform(epochs.get_data())))
evokeds_rec = []
for cls in np.unique(labels):
    evoked_rec = epochs_rec[cls].average()
    evokeds_rec.append(evoked_rec)
    if len(evoked_rec.ch_names) > 1:
        evoked_rec.apply_baseline((None,0)).plot_joint(title=cls,
                              **joint_args
                             )
    else:
        evoked_rec.plot(**ts_args)

# %%
from mne import combine_evoked, EvokedArray

contrast = combine_evoked(evokeds, weights=[-1,1])
_ = contrast.plot_joint(
    **joint_args
)


means_rec = hoda.inv_transform(hoda.transform(hoda.means_))
contrast_rec = means_rec[1]-means_rec[0]
contrast_rec = EvokedArray(tl.to_numpy(contrast_rec), epochs.info, epochs.tmin)
_ = contrast_rec.apply_baseline((None,0)).plot_joint(
    **joint_args
)

# %%
rec_diff = combine_evoked([contrast, contrast_rec], weights=[1,-1])
_ = rec_diff.apply_baseline((None,0)).plot_joint(
    **joint_args
)
