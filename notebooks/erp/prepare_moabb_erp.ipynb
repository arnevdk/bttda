# %%
from moabb.paradigms import P300
from moabb.datasets import *

paradigm = P300(resample=48)
datasets = paradigm.datasets

exclude = [
    # Did not download
    'ErpCore2021-N2pc',
    'Sosulski2019',
    # Not included
    'DemonsP300',
    'FakeVirtualRealityDataset-p300-21-1--60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60--120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120--target-nontarget--c3-cz-c4',
]
#datasets = [d for d in datasets if d.code not in exclude and not d.code.startswith('Fake')]
"""
datasets=[
    BNCI2014_008(),
    BNCI2014_009(),
    BNCI2015_003(),
    BI2012(),
    BI2013a(),
    BI2014a(),
    BI2014b(),
    BI2015a(),
    BI2015b(),
    Cattan2019_VR(),
    EPFLP300(),
    Huebner2017(),
    Huebner2018(),
    Lee2019_ERP(),
]"""
datasets = [BNCI2014_008()]
for dataset in datasets:
    print(dataset.code)
# Out:
# BNCI2014-008
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/fake.py:93: RuntimeWarning: Setting non-standard config type: "MNE_DATASETS_FAKEDATASET-IMAGERY-10-2--60-60--120-120--FAKE1-FAKE2-FAKE3--C3-CZ-C4_PATH"
#   set_config(key, temp_dir)
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/fake.py:93: RuntimeWarning: Setting non-standard config type: "MNE_DATASETS_FAKEVIRTUALREALITYDATASET-P300-21-1--60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60-60--120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120-120--TARGET-NONTARGET--C3-CZ-C4_PATH"
#   set_config(key, temp_dir)

# %%
from tqdm import tqdm

cache_config = dict(
    use=True,
    save_raw=False,
    save_epochs=False,
    save_array=True,
    overwrite_raw=False,
    overwrite_epochs=False,
    overwrite_array=False,
)
for dataset in datasets:
    n_subjects = len(dataset.subject_list)
    for si, subject in tqdm(list(enumerate(dataset.subject_list)), desc=f'Processing {dataset.code}'):
        try:
            paradigm.get_data(dataset, subjects=[subject], cache_config=cache_config)
        except Exception as e:
            print(e)
    print()
# Out:
# Processing BNCI2014-008:  75%|███████▌  | 6/8 [00:01<00:00,  4.99it/s]Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/008-2014/A07.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/008-2014/A07.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#
#   0%|                                              | 0.00/21.5M [00:00<?, ?B/s]
#   1%|▍                                     | 256k/21.5M [00:00<00:08, 2.55MB/s]
#  14%|█████▎                               | 3.07M/21.5M [00:00<00:01, 17.5MB/s]
#  67%|████████████████████████▉            | 14.5M/21.5M [00:00<00:00, 61.6MB/s]
# 100%|█████████████████████████████████████| 21.5M/21.5M [00:00<00:00, 12.4GB/s]
# SHA256 hash of downloaded file: 444d9da58332f58e89e7cdd39f9d9e7b0cb8ee4fd01ce03ef3ce57e53068f47c
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 4200 events (all good), 0 – 1 s (baseline off), ~65.9 MiB, data loaded,
#  'Target': 700
#  'NonTarget': 3500>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-bnci2014-008/dataset_description.json'...
# Processing BNCI2014-008: 100%|██████████| 8/8 [00:35<00:00,  4.45s/it]
