# %%
from moabb.paradigms import MotorImagery
from moabb.datasets import *

sfreq=250
n_classes=3
paradigm = MotorImagery(resample=sfreq, n_classes=n_classes)

datasets = paradigm.datasets
datasets = [
    AlexMI(),
    BNCI2014_001(),
    #Zhou2016(),
    #Weibo2014(),
    #Schirrmeister2017()
]
for dataset in datasets:
    print(dataset.code)
# Out:
# Choosing from all possible events
# AlexandreMotorImagery
# BNCI2014-001

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.preprocessing import FunctionTransformer
from classification_mi import stf_transform

cache_config = dict(
    use=True,
    save_raw=False,
    save_epochs=False,
    save_array=True,
    overwrite_raw=False,
    overwrite_epochs=False,
    overwrite_array=True,
)
for dataset in datasets:
    print(f'dataset: {dataset.code}, classes: {dataset.event_id}')
    n_subjects = len(dataset.subject_list)
    events = list(dataset.event_id.keys())[:n_classes]
    paradigm = MotorImagery(events=events, n_classes=n_classes, resample=sfreq)
    for subject in dataset.subject_list:
        print(f'Processing {dataset.code} subject {subject}/{n_subjects} ...')
        X,y,meta = paradigm.get_data(
            dataset,
            subjects=[subject],
            cache_config=cache_config,
            postprocess_pipeline = FunctionTransformer(stf_transform)
 
        )
# Out:
# dataset: AlexandreMotorImagery, classes: {'right_hand': 2, 'feet': 3, 'rest': 4}
# Processing AlexandreMotorImagery subject 1/8 ...
# Executing the following operations:
# Downloading data from 'https://zenodo.org/record/806023/files/subject1.raw.fif' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-alexeeg-data/record/806023/files/subject1.raw.fif'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 17.3M/17.3M [00:00<00:00, 61.6GB/s]
# SHA256 hash of downloaded file: 8e2897c11600687e34e3719d41c369365f86f97f0c1399cc246730e4f816bd93
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 60 events (all good), 0 – 3 s (baseline off), ~11.3 MiB, data loaded,
#  'right_hand': 20
#  'feet': 20
#  'rest': 20>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-alexandre-motor-imagery/dataset_description.json'...
# Processing AlexandreMotorImagery subject 2/8 ...
# Executing the following operations:
# Downloading data from 'https://zenodo.org/record/806023/files/subject2.raw.fif' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-alexeeg-data/record/806023/files/subject2.raw.fif'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 17.2M/17.2M [00:00<00:00, 59.6GB/s]
# SHA256 hash of downloaded file: 24d5a755da7884424b3fa7318d7decc2b42098a30cda9c8da45231ae14e88a39
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 60 events (all good), 0 – 3 s (baseline off), ~11.3 MiB, data loaded,
#  'right_hand': 20
#  'feet': 20
#  'rest': 20>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-alexandre-motor-imagery/dataset_description.json'...
# Processing AlexandreMotorImagery subject 3/8 ...
# Executing the following operations:
# Downloading data from 'https://zenodo.org/record/806023/files/subject3.raw.fif' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-alexeeg-data/record/806023/files/subject3.raw.fif'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 17.2M/17.2M [00:00<00:00, 64.1GB/s]
# SHA256 hash of downloaded file: 0ae95dac4c432cf4ecc7fb225593a84ffa6a4049c2d4f77fccc8b93e1ee85734
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 60 events (all good), 0 – 3 s (baseline off), ~11.3 MiB, data loaded,
#  'right_hand': 20
#  'feet': 20
#  'rest': 20>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-alexandre-motor-imagery/dataset_description.json'...
# Processing AlexandreMotorImagery subject 4/8 ...
# Executing the following operations:
# Downloading data from 'https://zenodo.org/record/806023/files/subject4.raw.fif' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-alexeeg-data/record/806023/files/subject4.raw.fif'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 17.2M/17.2M [00:00<00:00, 39.7GB/s]
# SHA256 hash of downloaded file: 0bcd939780b098bf889da8b2bd882891ddc339dadd0b9b2f6cb659d3d40b73f8
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 60 events (all good), 0 – 3 s (baseline off), ~11.3 MiB, data loaded,
#  'right_hand': 20
#  'feet': 20
#  'rest': 20>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-alexandre-motor-imagery/dataset_description.json'...
# Processing AlexandreMotorImagery subject 5/8 ...
# Executing the following operations:
# Downloading data from 'https://zenodo.org/record/806023/files/subject5.raw.fif' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-alexeeg-data/record/806023/files/subject5.raw.fif'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 17.3M/17.3M [00:00<00:00, 39.8GB/s]
# SHA256 hash of downloaded file: e9eef9c93bd2157940fa6681dbea27ce37ec9cbd890e21c8fb91f6a1aea2bc87
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 60 events (all good), 0 – 3 s (baseline off), ~11.3 MiB, data loaded,
#  'right_hand': 20
#  'feet': 20
#  'rest': 20>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-alexandre-motor-imagery/dataset_description.json'...
# Processing AlexandreMotorImagery subject 6/8 ...
# Executing the following operations:
# Downloading data from 'https://zenodo.org/record/806023/files/subject6.raw.fif' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-alexeeg-data/record/806023/files/subject6.raw.fif'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 17.5M/17.5M [00:00<00:00, 47.4GB/s]
# SHA256 hash of downloaded file: 2cfa5e1290f2648795354e43b8affac1ea562f3edafe39cf9c888ffe113d4800
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 60 events (all good), 0 – 3 s (baseline off), ~11.3 MiB, data loaded,
#  'right_hand': 20
#  'feet': 20
#  'rest': 20>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-alexandre-motor-imagery/dataset_description.json'...
# Processing AlexandreMotorImagery subject 7/8 ...
# Executing the following operations:
# Downloading data from 'https://zenodo.org/record/806023/files/subject7.raw.fif' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-alexeeg-data/record/806023/files/subject7.raw.fif'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 17.4M/17.4M [00:00<00:00, 40.5GB/s]
# SHA256 hash of downloaded file: 6291ad40703ef2e341f49a76510d8fed63af2dc6ce598b531e7615745c86525d
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 60 events (all good), 0 – 3 s (baseline off), ~11.3 MiB, data loaded,
#  'right_hand': 20
#  'feet': 20
#  'rest': 20>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-alexandre-motor-imagery/dataset_description.json'...
# Processing AlexandreMotorImagery subject 8/8 ...
# Executing the following operations:
# Downloading data from 'https://zenodo.org/record/806023/files/subject8.raw.fif' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-alexeeg-data/record/806023/files/subject8.raw.fif'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 17.4M/17.4M [00:00<00:00, 36.0GB/s]
# SHA256 hash of downloaded file: 33e365add854908899d22898fcda1635e04bd865e28a81e0bd8c5bb0fe0550f4
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 60 events (all good), 0 – 3 s (baseline off), ~11.3 MiB, data loaded,
#  'right_hand': 20
#  'feet': 20
#  'rest': 20>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-alexandre-motor-imagery/dataset_description.json'...
# dataset: BNCI2014-001, classes: {'left_hand': 1, 'right_hand': 2, 'feet': 3, 'tongue': 4}
# Processing BNCI2014-001 subject 1/9 ...
# Executing the following operations:
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A01T.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A01T.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 42.8M/42.8M [00:00<00:00, 161GB/s]
# SHA256 hash of downloaded file: 054f02e70cf9c4ada1517e9b9864f45407939c1062c6793516585c6f511d0325
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A01E.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A01E.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 43.8M/43.8M [00:00<00:00, 103GB/s]
# SHA256 hash of downloaded file: 53d415f39c3d7b0c88b894d7b08d99bcdfe855ede63831d3691af1a45607fb62
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-bnci2014-001/dataset_description.json'...
# Processing BNCI2014-001 subject 2/9 ...
# Executing the following operations:
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A02T.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A02T.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 43.1M/43.1M [00:00<00:00, 77.6GB/s]
# SHA256 hash of downloaded file: 5ddd5cb520b1692c3ba1363f48d98f58f0e46f3699ee50d749947950fc39db27
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A02E.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A02E.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 44.2M/44.2M [00:00<00:00, 96.4GB/s]
# SHA256 hash of downloaded file: d63c454005d3a9b41d8440629482e855afc823339bdd0b5721842a7ee9cc7b12
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-bnci2014-001/dataset_description.json'...
# Processing BNCI2014-001 subject 3/9 ...
# Executing the following operations:
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A03T.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A03T.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 44.1M/44.1M [00:00<00:00, 164GB/s]
# SHA256 hash of downloaded file: 7e731ee8b681d5da6ecb11ae1d4e64b1653c7f15aad5d6b7620b25ce53141e80
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A03E.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A03E.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 42.3M/42.3M [00:00<00:00, 82.0GB/s]
# SHA256 hash of downloaded file: d4229267ec7624fa8bd3af5cbebac17f415f7c722de6cb676748f8cb3b717d97
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-bnci2014-001/dataset_description.json'...
# Processing BNCI2014-001 subject 4/9 ...
# Executing the following operations:
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A04T.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A04T.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 37.2M/37.2M [00:00<00:00, 89.8GB/s]
# SHA256 hash of downloaded file: 15850d81b95fc88cc8b9589eb9b713d49fa071e28adaf32d675b3eaa30591d6e
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A04E.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A04E.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 41.7M/41.7M [00:00<00:00, 104GB/s]
# SHA256 hash of downloaded file: 81916dff2c12997974ba50ffc311da006ea66e525010d010765f0047e771c86a
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-bnci2014-001/dataset_description.json'...
# Processing BNCI2014-001 subject 5/9 ...
# Executing the following operations:
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A05T.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A05T.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 42.5M/42.5M [00:00<00:00, 40.3GB/s]
# SHA256 hash of downloaded file: 77387d3b669f4ed9a7c1dac4dcba4c2c40c8910bae20fb961bb7cf5a94912950
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A05E.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A05E.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 44.4M/44.4M [00:00<00:00, 171GB/s]
# SHA256 hash of downloaded file: 8b357470865610c28b2f1d351beac247a56a856f02b2859d650736eb2ef77808
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-bnci2014-001/dataset_description.json'...
# Processing BNCI2014-001 subject 6/9 ...
# Executing the following operations:
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A06T.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A06T.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 44.6M/44.6M [00:00<00:00, 111GB/s]
# SHA256 hash of downloaded file: 4dc3be1b0d60279134d1220323c73c68cf73799339a7fb224087a3c560a9a7e2
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A06E.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A06E.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 43.4M/43.4M [00:00<00:00, 168GB/s]
# SHA256 hash of downloaded file: bf67a40621b74b6af7a986c2f6edfff7fc2bbbca237aadd07b575893032998d1
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-bnci2014-001/dataset_description.json'...
# Processing BNCI2014-001 subject 7/9 ...
# Executing the following operations:
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A07T.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A07T.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 42.8M/42.8M [00:00<00:00, 170GB/s]
# SHA256 hash of downloaded file: 43b6bbef0be78f0ac2b66cb2d9679091f1f5b7f0a5d4ebef73d2c7cc8e11aa96
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A07E.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A07E.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|█████████████████████████████████████| 42.2M/42.2M [00:00<00:00, 93.4GB/s]
# SHA256 hash of downloaded file: b9aaec73dcee002fab84ee98e938039a67bf6a3cbf4fc86d5d8df198cfe4c323
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-bnci2014-001/dataset_description.json'...
# Processing BNCI2014-001 subject 8/9 ...
# Executing the following operations:
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A08T.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A08T.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 45.0M/45.0M [00:00<00:00, 113GB/s]
# SHA256 hash of downloaded file: 7a4b3bd602d5bc307d3f4527fca2cf076659e94aca584dd64f6286fd413a82f2
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A08E.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A08E.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 46.3M/46.3M [00:00<00:00, 167GB/s]
# SHA256 hash of downloaded file: 0eedbd89790c7d621c8eef68065ddecf80d437bbbcf60321d9253e2305f294f7
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-bnci2014-001/dataset_description.json'...
# Processing BNCI2014-001 subject 9/9 ...
# Executing the following operations:
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A09T.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A09T.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 44.8M/44.8M [00:00<00:00, 111GB/s]
# SHA256 hash of downloaded file: b28d8a262c779c8cad9cc80ee6aa9c5691cfa6617c03befe490a090347ebd15c
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A09E.mat' to file '/lustre1/scratch/352/vsc35289/mne_data/MNE-bnci-data/database/data-sets/001-2014/A09E.mat'.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 44.8M/44.8M [00:00<00:00, 114GB/s]
# SHA256 hash of downloaded file: 5d79649a42df9d51215def8ffbdaf1c3f76c54b88b9bbaae721e8c6fd972cc36
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# /data/leuven/352/vsc35289/miniconda3/envs/bttda/lib/python3.11/site-packages/moabb/datasets/preprocessing.py:278: UserWarning: warnEpochs <Epochs | 36 events (all good), 2 – 6 s (baseline off), ~6.1 MiB, data loaded,
#  'left_hand': 12
#  'right_hand': 12
#  'feet': 12>
#   warn(f"warnEpochs {epochs}")
# Writing '/scratch/leuven/352/vsc35289/mne_data/MNE-BIDS-bnci2014-001/dataset_description.json'...
